sensors_data
# Out:
#          sensor1     sensor2     sensor3     sensor4     sensor5     sensor6  \
# 0     110.711268  129.230445   75.463322  113.511095  121.694411  145.984667
# 1      95.702235  141.424797   85.373816  116.378093  125.321930  150.329013
# 2     103.938672  141.003192   85.000567  118.441676  127.472223  153.874649
# 3     102.529665  129.153521   82.754072  115.081102  126.914194  151.456218
# 4     105.295093  132.886683   84.703097  113.640929  130.131858  149.111901
# ...          ...         ...         ...         ...         ...         ...
# 2438  132.039673  107.624018  112.220684   75.200003  157.196528  144.639356
# 2439  132.004125  116.206713  111.118276   74.674690  153.494497  148.584344
# 2440  123.050332  111.866013  106.142539   80.785180  151.950031  143.995262
# 2441  129.807045  107.722496  106.922565   74.786681  156.269596  139.113293
# 2442  126.844547  102.736457  111.524733   75.405400  148.601986  132.389928
#
#          sensor7     sensor8
# 0     114.347158  128.542893
# 1     112.922390  143.549881
# 2     109.590742  137.516658
# 3     112.408224  137.247646
# 4     114.497900  133.147438
# ...          ...         ...
# 2438  123.040753  120.294057
# 2439  128.491874  122.094259
# 2440  130.851418  118.303942
# 2441  140.649493  123.911561
# 2442  136.321958  119.875334
#
# [2443 rows x 8 columns]

# %% [markdown]
# # RobustScaler

# %%
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
sensors_data = scaler.fit_transform(sensors_data)

# %% [markdown]
# # Split the data into training and testing sets

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(sensors_data, position_data, test_size=0.2, random_state=42)

# %%
X_train
# Out:
# array([[ 0.37419762,  0.84031713,  0.32219657, ...,  0.0622908 ,
#         -1.07944284,  0.29993489],
#        [-0.80264498,  0.73419508, -1.0568621 , ...,  0.88709457,
#         -0.37630668,  0.67016769],
#        [ 0.96419619,  0.63592922,  0.61585019, ..., -0.34719748,
#         -0.48876928, -1.40779326],
#        ...,
#        [-0.45316215, -0.60885284, -0.71288408, ...,  0.53635548,
#          0.36532891,  0.70049343],
#        [-0.9909003 , -0.67660219, -0.29142597, ...,  0.01329102,
#          0.0660432 ,  0.42855096],
#        [ 0.12387799,  0.19793301,  0.55278693, ..., -0.41876369,
#         -1.16423649, -0.70706112]])

# %%
y_train
# Out:
#           Pos X      Pos Y  Pos Z
# 233   59.678117  54.115562 -50.68
# 433  -19.191177  62.122007 -42.68
# 1430  45.890531  69.708995  -2.80
# 307   48.255475  30.881811 -47.72
# 2197  46.396180  30.387490  27.88
# ...         ...        ...    ...
# 1638  11.378450  42.552019   5.52
# 1095 -36.900143  69.397796 -16.20
# 1130 -50.886002  67.974162 -14.80
# 1294 -28.195387  33.407817  -8.24
# 860   59.591095  54.630197 -25.60
#
# [1954 rows x 3 columns]

# %% [markdown]
# # Machine Learning

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.ensemble import GradientBoostingRegressor

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, median_absolute_error
from sklearn.metrics import explained_variance_score, max_error, mean_squared_log_error

# %%
# Initialize the models
models = [LinearRegression(), DecisionTreeRegressor(), RandomForestRegressor(), KNeighborsRegressor(),  XGBRegressor()]

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, median_absolute_error, explained_variance_score
import time

# Train and evaluate each model
for model in models:
    start_time = time.time()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    end_time = time.time()
    
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    
    print(type(model).__name__)
    print("Accuracy:", model.score(X_test, y_test))
    print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
    print("Root Mean Squared Error:", rmse)
    print("R2 Score:", r2_score(y_test, y_pred))
    print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
    print("Median Absolute Error:", median_absolute_error(y_test, y_pred))
    print("Explained Variance Score:", explained_variance_score(y_test, y_pred))
    print("Time taken:", end_time - start_time)
    print("="*100)
# Out:
# LinearRegression
# Accuracy: 0.9189933463544077
# Mean Squared Error: 38.97621497360007
# Root Mean Squared Error: 6.23554278238534
# R2 Score: 0.9189933463544077
# Mean Absolute Error: 4.983770113730059
# Median Absolute Error: 4.191307786944008
# Explained Variance Score: 0.9193892497581758
# Time taken: 0.002499818801879883
# ====================================================================================================
# DecisionTreeRegressor
# Accuracy: 0.7789024438835274
# Mean Squared Error: 108.67639421477702
# Root Mean Squared Error: 10.402006470739627
# R2 Score: 0.7789024438835274
# Mean Absolute Error: 6.907709471216237
# Median Absolute Error: 3.7506387910312338
# Explained Variance Score: 0.7795724406837093
# Time taken: 0.009502410888671875
# ====================================================================================================
# RandomForestRegressor
# Accuracy: 0.9270846333708508
# Mean Squared Error: 37.5251316995592
# Root Mean Squared Error: 6.1023158043977
# R2 Score: 0.9270846333708508
# Mean Absolute Error: 4.556956308965176
# Median Absolute Error: 3.4372661469207144
# Explained Variance Score: 0.9271722125600764
# Time taken: 0.5865519046783447
# ====================================================================================================
# KNeighborsRegressor
# Accuracy: 0.9373700463309754
# Mean Squared Error: 32.99881517003289
# Root Mean Squared Error: 5.712884798084289
# R2 Score: 0.9373700463309754
# Mean Absolute Error: 3.87104182898743
# Median Absolute Error: 2.3130442498443053
# Explained Variance Score: 0.9373760652797775
# Time taken: 0.00500035285949707
# ====================================================================================================
# XGBRegressor
# Accuracy: 0.9141230893849542
# Mean Squared Error: 44.55969864791971
# Root Mean Squared Error: 6.642821737845903
# R2 Score: 0.9141230893849542
# Mean Absolute Error: 4.887488612808948
# Median Absolute Error: 3.4038499337480133
# Explained Variance Score: 0.9142041203283716
# Time taken: 0.2805178165435791
# ====================================================================================================

# %% [markdown]
# # Cross Validation

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score, mean_absolute_error
import time


X = sensors_data
y = position_data

# convert numpy array into pandas dataframe
X = pd.DataFrame(X)
y = pd.DataFrame(y)

#Define models
models = [LinearRegression(), DecisionTreeRegressor(), RandomForestRegressor(), KNeighborsRegressor(), XGBRegressor()]

#Define k-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

#Train and evaluate each model using k-fold cross-validation
for model in models:
    # Evaluate the performance of the model using k-fold cross-validation
    scores_mse = []
    scores_mae = []
    scores_rmse = []
    times = []
    for i, (train_index, test_index) in enumerate(kfold.split(X)):
        start_time = time.time()
        
        X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[test_index]
        y_train_fold, y_val_fold = y.iloc[train_index], y.iloc[test_index]
        model.fit(X_train_fold, y_train_fold)
        y_pred_fold = model.predict(X_val_fold)
        
        
        mse = mean_squared_error(y_val_fold, y_pred_fold)
        mae = mean_absolute_error(y_val_fold, y_pred_fold)
        rmse = np.sqrt(mse)
        end_time = time.time()
        time_taken = end_time - start_time
        scores_mse.append(mse)
        scores_mae.append(mae)
        scores_rmse.append(rmse)
        times.append(time_taken)
        print(f"Model: {type(model).__name__}")
        print(f"Fold {i+1} - Mean Squared Error (MSE): {mse:.2f}")
        print(f"Fold {i+1} - Mean Absolute Error (MAE): {mae:.2f}")
        print(f"Fold {i+1} - Root Mean Squared Error (RMSE): {rmse:.2f}")
        print(f"Fold {i+1} - Time taken: {time_taken:.2f} seconds")
    
    # Calculate mean time and results for all the folds
    mean_mse = np.mean(scores_mse)
    mean_mae = np.mean(scores_mae)
    mean_rmse = np.mean(scores_rmse)
    mean_time = np.mean(times)

    # Print the mean results of the folds
    print(f"Mean MSE: {mean_mse:.2f}")
    print(f"Mean MAE: {mean_mae:.2f}")
    print(f"Mean RMSE: {mean_rmse:.2f}")
    print(f"Mean time: {mean_time:.2f} seconds")
    print("-" * 50)
# Out:
# Model: LinearRegression
# Fold 1 - Mean Squared Error (MSE): 38.98
# Fold 1 - Mean Absolute Error (MAE): 4.98
# Fold 1 - Root Mean Squared Error (RMSE): 6.24
# Fold 1 - Time taken: 0.00 seconds
# Model: LinearRegression
# Fold 2 - Mean Squared Error (MSE): 40.08
# Fold 2 - Mean Absolute Error (MAE): 5.04
# Fold 2 - Root Mean Squared Error (RMSE): 6.33
# Fold 2 - Time taken: 0.00 seconds
# Model: LinearRegression
# Fold 3 - Mean Squared Error (MSE): 37.72
# Fold 3 - Mean Absolute Error (MAE): 4.91
# Fold 3 - Root Mean Squared Error (RMSE): 6.14
# Fold 3 - Time taken: 0.00 seconds
# Model: LinearRegression
# Fold 4 - Mean Squared Error (MSE): 43.59
# Fold 4 - Mean Absolute Error (MAE): 5.26
# Fold 4 - Root Mean Squared Error (RMSE): 6.60
# Fold 4 - Time taken: 0.00 seconds
# Model: LinearRegression
# Fold 5 - Mean Squared Error (MSE): 37.82
# Fold 5 - Mean Absolute Error (MAE): 4.88
# Fold 5 - Root Mean Squared Error (RMSE): 6.15
# Fold 5 - Time taken: 0.00 seconds
# Mean MSE: 39.64
# Mean MAE: 5.02
# Mean RMSE: 6.29
# Mean time: 0.00 seconds
# --------------------------------------------------
# Model: DecisionTreeRegressor
# Fold 1 - Mean Squared Error (MSE): 106.89
# Fold 1 - Mean Absolute Error (MAE): 6.77
# Fold 1 - Root Mean Squared Error (RMSE): 10.34
# Fold 1 - Time taken: 0.01 seconds
# Model: DecisionTreeRegressor
# Fold 2 - Mean Squared Error (MSE): 103.10
# Fold 2 - Mean Absolute Error (MAE): 6.47
# Fold 2 - Root Mean Squared Error (RMSE): 10.15
# Fold 2 - Time taken: 0.01 seconds
# Model: DecisionTreeRegressor
# Fold 3 - Mean Squared Error (MSE): 98.67
# Fold 3 - Mean Absolute Error (MAE): 6.37
# Fold 3 - Root Mean Squared Error (RMSE): 9.93
# Fold 3 - Time taken: 0.01 seconds
# Model: DecisionTreeRegressor
# Fold 4 - Mean Squared Error (MSE): 106.94
# Fold 4 - Mean Absolute Error (MAE): 6.90
# Fold 4 - Root Mean Squared Error (RMSE): 10.34
# Fold 4 - Time taken: 0.01 seconds
# Model: DecisionTreeRegressor
# Fold 5 - Mean Squared Error (MSE): 98.56
# Fold 5 - Mean Absolute Error (MAE): 6.35
# Fold 5 - Root Mean Squared Error (RMSE): 9.93
# Fold 5 - Time taken: 0.01 seconds
# Mean MSE: 102.83
# Mean MAE: 6.57
# Mean RMSE: 10.14
# Mean time: 0.01 seconds
# --------------------------------------------------
# Model: RandomForestRegressor
# Fold 1 - Mean Squared Error (MSE): 37.54
# Fold 1 - Mean Absolute Error (MAE): 4.53
# Fold 1 - Root Mean Squared Error (RMSE): 6.13
# Fold 1 - Time taken: 0.57 seconds
# Model: RandomForestRegressor
# Fold 2 - Mean Squared Error (MSE): 40.44
# Fold 2 - Mean Absolute Error (MAE): 4.67
# Fold 2 - Root Mean Squared Error (RMSE): 6.36
# Fold 2 - Time taken: 0.59 seconds
# Model: RandomForestRegressor
# Fold 3 - Mean Squared Error (MSE): 37.05
# Fold 3 - Mean Absolute Error (MAE): 4.54
# Fold 3 - Root Mean Squared Error (RMSE): 6.09
# Fold 3 - Time taken: 0.57 seconds
# Model: RandomForestRegressor
# Fold 4 - Mean Squared Error (MSE): 45.57
# Fold 4 - Mean Absolute Error (MAE): 5.03
# Fold 4 - Root Mean Squared Error (RMSE): 6.75
# Fold 4 - Time taken: 0.58 seconds
# Model: RandomForestRegressor
# Fold 5 - Mean Squared Error (MSE): 36.47
# Fold 5 - Mean Absolute Error (MAE): 4.49
# Fold 5 - Root Mean Squared Error (RMSE): 6.04
# Fold 5 - Time taken: 0.57 seconds
# Mean MSE: 39.41
# Mean MAE: 4.65
# Mean RMSE: 6.27
# Mean time: 0.58 seconds
# --------------------------------------------------
# Model: KNeighborsRegressor
# Fold 1 - Mean Squared Error (MSE): 33.00
# Fold 1 - Mean Absolute Error (MAE): 3.87
# Fold 1 - Root Mean Squared Error (RMSE): 5.74
# Fold 1 - Time taken: 0.01 seconds
# Model: KNeighborsRegressor
# Fold 2 - Mean Squared Error (MSE): 31.58
# Fold 2 - Mean Absolute Error (MAE): 3.94
# Fold 2 - Root Mean Squared Error (RMSE): 5.62
# Fold 2 - Time taken: 0.01 seconds
# Model: KNeighborsRegressor
# Fold 3 - Mean Squared Error (MSE): 33.70
# Fold 3 - Mean Absolute Error (MAE): 4.00
# Fold 3 - Root Mean Squared Error (RMSE): 5.81
# Fold 3 - Time taken: 0.01 seconds
# Model: KNeighborsRegressor
# Fold 4 - Mean Squared Error (MSE): 36.95
# Fold 4 - Mean Absolute Error (MAE): 4.20
# Fold 4 - Root Mean Squared Error (RMSE): 6.08
# Fold 4 - Time taken: 0.01 seconds
# Model: KNeighborsRegressor
# Fold 5 - Mean Squared Error (MSE): 29.52
# Fold 5 - Mean Absolute Error (MAE): 3.76
# Fold 5 - Root Mean Squared Error (RMSE): 5.43
# Fold 5 - Time taken: 0.01 seconds
# Mean MSE: 32.95
# Mean MAE: 3.96
# Mean RMSE: 5.74
# Mean time: 0.01 seconds
# --------------------------------------------------
# Model: XGBRegressor
# Fold 1 - Mean Squared Error (MSE): 44.56
# Fold 1 - Mean Absolute Error (MAE): 4.89
# Fold 1 - Root Mean Squared Error (RMSE): 6.68
# Fold 1 - Time taken: 0.27 seconds
# Model: XGBRegressor
# Fold 2 - Mean Squared Error (MSE): 42.91
# Fold 2 - Mean Absolute Error (MAE): 4.83
# Fold 2 - Root Mean Squared Error (RMSE): 6.55
# Fold 2 - Time taken: 0.27 seconds
# Model: XGBRegressor
# Fold 3 - Mean Squared Error (MSE): 45.81
# Fold 3 - Mean Absolute Error (MAE): 5.03
# Fold 3 - Root Mean Squared Error (RMSE): 6.77
# Fold 3 - Time taken: 2.24 seconds
# Model: XGBRegressor
# Fold 4 - Mean Squared Error (MSE): 48.07
# Fold 4 - Mean Absolute Error (MAE): 5.17
# Fold 4 - Root Mean Squared Error (RMSE): 6.93
# Fold 4 - Time taken: 2.14 seconds
# Model: XGBRegressor
# Fold 5 - Mean Squared Error (MSE): 43.48
# Fold 5 - Mean Absolute Error (MAE): 4.88
# Fold 5 - Root Mean Squared Error (RMSE): 6.59
# Fold 5 - Time taken: 2.00 seconds
# Mean MSE: 44.97
# Mean MAE: 4.96
# Mean RMSE: 6.70
# Mean time: 1.38 seconds
# --------------------------------------------------

# %% [markdown]
# # Excel File Conversion

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score, mean_absolute_error
import time


X = sensors_data
y = position_data

# convert numpy array into pandas dataframe
X = pd.DataFrame(X)
y = pd.DataFrame(y)

# Define models
models = [LinearRegression(), DecisionTreeRegressor(), RandomForestRegressor(), KNeighborsRegressor(), XGBRegressor()]

# Define k-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# Create empty dictionary to store the results
results_dict = {
    "Model": [],
    "Fold": [],
    "Mean Squared Error (MSE)": [],
    "Mean Absolute Error (MAE)": [],
    "Root Mean Squared Error (RMSE)": [],
    "Time taken": []
}

# Train and evaluate each model using k-fold cross-validation
for model in models:
    # Evaluate the performance of the model using k-fold cross-validation
    scores_mse = []
    scores_mae = []
    scores_rmse = []
    times = []
    for i, (train_index, test_index) in enumerate(kfold.split(X)):
        start_time = time.time()
        
        X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[test_index]
        y_train_fold, y_val_fold = y.iloc[train_index], y.iloc[test_index]
        model.fit(X_train_fold, y_train_fold)
        y_pred_fold = model.predict(X_val_fold)
        
        
        mse = mean_squared_error(y_val_fold, y_pred_fold)
        mae = mean_absolute_error(y_val_fold, y_pred_fold)
        rmse = np.sqrt(mse)
        end_time = time.time()
        time_taken = end_time - start_time
        scores_mse.append(mse)
        scores_mae.append(mae)
        scores_rmse.append(rmse)
        times.append(time_taken)
        
        # Add the results to the dictionary
        results_dict["Model"].append(type(model).__name__)
        results_dict["Fold"].append(i+1)
        results_dict["Mean Squared Error (MSE)"].append(mse)
        results_dict["Mean Absolute Error (MAE)"].append(mae)
        results_dict["Root Mean Squared Error (RMSE)"].append(rmse)
        results_dict["Time taken"].append(time_taken)
        
        print(f"Model: {type(model).__name__}")
        print(f"Fold {i+1} - Mean Squared Error (MSE): {mse:.2f}")
        print(f"Fold {i+1} - Mean Absolute Error (MAE): {mae:.2f}")
        print(f"Fold {i+1} - Root Mean Squared Error (RMSE): {rmse:.2f}")
        print(f"Fold {i+1} - Time taken: {time_taken:.2f} seconds")
    
    # Calculate mean time and results for all the folds
    mean_mse = np.mean(scores_mse)
    mean_mae = np.mean(scores_mae)
    mean_rmse = np.mean(scores_rmse)
    mean_time = np.mean(times)

    # Add the mean results to the dictionary
    results_dict["Model"].append(type(model).__name__)
    results_dict["Fold"].append("Mean")
    results_dict["Mean Squared Error (MSE)"].append(mean_mse)
    results_dict["Mean Absolute Error (MAE)"].append(mean_mae)
    results_dict["Root Mean Squared Error (RMSE)"].append(mean_rmse)
    results_dict["Time taken"].append(mean_time)

    print(f"Model: {type(model).__name__}")
    print(f"Mean - Mean Squared Error (MSE): {mean_mse:.2f}")
    print(f"Mean - Mean Absolute Error (MAE): {mean_mae:.2f}")
    print(f"Mean - Root Mean Squared Error (RMSE): {mean_rmse:.2f}")
    print(f"Mean - Time taken: {mean_time:.2f} seconds")

    
#Convert the results dictionary into a pandas dataframe
results_df = pd.DataFrame.from_dict(results_dict)

#Save the results to an Excel file
results_df.to_excel("RobustScaler - (1-8) results.xlsx", index=False)

#Print a message indicating that the results have been saved to a file
print("Results saved to results.xlsx file")
# Out:
# Model: LinearRegression
# Fold 1 - Mean Squared Error (MSE): 38.98
# Fold 1 - Mean Absolute Error (MAE): 4.98
# Fold 1 - Root Mean Squared Error (RMSE): 6.24
# Fold 1 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 2 - Mean Squared Error (MSE): 40.08
# Fold 2 - Mean Absolute Error (MAE): 5.04
# Fold 2 - Root Mean Squared Error (RMSE): 6.33
# Fold 2 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 3 - Mean Squared Error (MSE): 37.72
# Fold 3 - Mean Absolute Error (MAE): 4.91
# Fold 3 - Root Mean Squared Error (RMSE): 6.14
# Fold 3 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 4 - Mean Squared Error (MSE): 43.59
# Fold 4 - Mean Absolute Error (MAE): 5.26
# Fold 4 - Root Mean Squared Error (RMSE): 6.60
# Fold 4 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 5 - Mean Squared Error (MSE): 37.82
# Fold 5 - Mean Absolute Error (MAE): 4.88
# Fold 5 - Root Mean Squared Error (RMSE): 6.15
# Fold 5 - Time taken: 0.01 seconds
# Model: LinearRegression
# Mean - Mean Squared Error (MSE): 39.64
# Mean - Mean Absolute Error (MAE): 5.02
# Mean - Root Mean Squared Error (RMSE): 6.29
# Mean - Time taken: 0.01 seconds
# Model: DecisionTreeRegressor
# Fold 1 - Mean Squared Error (MSE): 106.43
# Fold 1 - Mean Absolute Error (MAE): 6.76
# Fold 1 - Root Mean Squared Error (RMSE): 10.32
# Fold 1 - Time taken: 0.02 seconds
# Model: DecisionTreeRegressor
# Fold 2 - Mean Squared Error (MSE): 106.95
# Fold 2 - Mean Absolute Error (MAE): 6.59
# Fold 2 - Root Mean Squared Error (RMSE): 10.34
# Fold 2 - Time taken: 0.03 seconds
# Model: DecisionTreeRegressor
# Fold 3 - Mean Squared Error (MSE): 106.60
# Fold 3 - Mean Absolute Error (MAE): 6.76
# Fold 3 - Root Mean Squared Error (RMSE): 10.32
# Fold 3 - Time taken: 0.02 seconds
# Model: DecisionTreeRegressor
# Fold 4 - Mean Squared Error (MSE): 103.22
# Fold 4 - Mean Absolute Error (MAE): 6.69
# Fold 4 - Root Mean Squared Error (RMSE): 10.16
# Fold 4 - Time taken: 0.02 seconds
# Model: DecisionTreeRegressor
# Fold 5 - Mean Squared Error (MSE): 98.87
# Fold 5 - Mean Absolute Error (MAE): 6.37
# Fold 5 - Root Mean Squared Error (RMSE): 9.94
# Fold 5 - Time taken: 0.02 seconds
# Model: DecisionTreeRegressor
# Mean - Mean Squared Error (MSE): 104.41
# Mean - Mean Absolute Error (MAE): 6.64
# Mean - Root Mean Squared Error (RMSE): 10.22
# Mean - Time taken: 0.02 seconds
# Model: RandomForestRegressor
# Fold 1 - Mean Squared Error (MSE): 37.27
# Fold 1 - Mean Absolute Error (MAE): 4.51
# Fold 1 - Root Mean Squared Error (RMSE): 6.10
# Fold 1 - Time taken: 1.02 seconds
# Model: RandomForestRegressor
# Fold 2 - Mean Squared Error (MSE): 40.33
# Fold 2 - Mean Absolute Error (MAE): 4.67
# Fold 2 - Root Mean Squared Error (RMSE): 6.35
# Fold 2 - Time taken: 1.05 seconds
# Model: RandomForestRegressor
# Fold 3 - Mean Squared Error (MSE): 36.98
# Fold 3 - Mean Absolute Error (MAE): 4.55
# Fold 3 - Root Mean Squared Error (RMSE): 6.08
# Fold 3 - Time taken: 1.03 seconds
# Model: RandomForestRegressor
# Fold 4 - Mean Squared Error (MSE): 44.81
# Fold 4 - Mean Absolute Error (MAE): 5.01
# Fold 4 - Root Mean Squared Error (RMSE): 6.69
# Fold 4 - Time taken: 1.02 seconds
# Model: RandomForestRegressor
# Fold 5 - Mean Squared Error (MSE): 36.86
# Fold 5 - Mean Absolute Error (MAE): 4.48
# Fold 5 - Root Mean Squared Error (RMSE): 6.07
# Fold 5 - Time taken: 1.08 seconds
# Model: RandomForestRegressor
# Mean - Mean Squared Error (MSE): 39.25
# Mean - Mean Absolute Error (MAE): 4.65
# Mean - Root Mean Squared Error (RMSE): 6.26
# Mean - Time taken: 1.04 seconds
# Model: KNeighborsRegressor
# Fold 1 - Mean Squared Error (MSE): 33.00
# Fold 1 - Mean Absolute Error (MAE): 3.87
# Fold 1 - Root Mean Squared Error (RMSE): 5.74
# Fold 1 - Time taken: 0.02 seconds
# Model: KNeighborsRegressor
# Fold 2 - Mean Squared Error (MSE): 31.58
# Fold 2 - Mean Absolute Error (MAE): 3.94
# Fold 2 - Root Mean Squared Error (RMSE): 5.62
# Fold 2 - Time taken: 0.02 seconds
# Model: KNeighborsRegressor
# Fold 3 - Mean Squared Error (MSE): 33.70
# Fold 3 - Mean Absolute Error (MAE): 4.00
# Fold 3 - Root Mean Squared Error (RMSE): 5.81
# Fold 3 - Time taken: 0.02 seconds
# Model: KNeighborsRegressor
# Fold 4 - Mean Squared Error (MSE): 36.95
# Fold 4 - Mean Absolute Error (MAE): 4.20
# Fold 4 - Root Mean Squared Error (RMSE): 6.08
# Fold 4 - Time taken: 0.02 seconds
# Model: KNeighborsRegressor
# Fold 5 - Mean Squared Error (MSE): 29.52
# Fold 5 - Mean Absolute Error (MAE): 3.76
# Fold 5 - Root Mean Squared Error (RMSE): 5.43
# Fold 5 - Time taken: 0.02 seconds
# Model: KNeighborsRegressor
# Mean - Mean Squared Error (MSE): 32.95
# Mean - Mean Absolute Error (MAE): 3.96
# Mean - Root Mean Squared Error (RMSE): 5.74
# Mean - Time taken: 0.02 seconds
# Model: XGBRegressor
# Fold 1 - Mean Squared Error (MSE): 44.56
# Fold 1 - Mean Absolute Error (MAE): 4.89
# Fold 1 - Root Mean Squared Error (RMSE): 6.68
# Fold 1 - Time taken: 2.17 seconds
# Model: XGBRegressor
# Fold 2 - Mean Squared Error (MSE): 42.91
# Fold 2 - Mean Absolute Error (MAE): 4.83
# Fold 2 - Root Mean Squared Error (RMSE): 6.55
# Fold 2 - Time taken: 2.02 seconds
# Model: XGBRegressor
# Fold 3 - Mean Squared Error (MSE): 45.81
# Fold 3 - Mean Absolute Error (MAE): 5.03
# Fold 3 - Root Mean Squared Error (RMSE): 6.77
# Fold 3 - Time taken: 2.10 seconds
# Model: XGBRegressor
# Fold 4 - Mean Squared Error (MSE): 48.07
# Fold 4 - Mean Absolute Error (MAE): 5.17
# Fold 4 - Root Mean Squared Error (RMSE): 6.93
# Fold 4 - Time taken: 4.01 seconds
# Model: XGBRegressor
# Fold 5 - Mean Squared Error (MSE): 43.48
# Fold 5 - Mean Absolute Error (MAE): 4.88
# Fold 5 - Root Mean Squared Error (RMSE): 6.59
# Fold 5 - Time taken: 4.09 seconds
# Model: XGBRegressor
# Mean - Mean Squared Error (MSE): 44.97
# Mean - Mean Absolute Error (MAE): 4.96
# Mean - Root Mean Squared Error (RMSE): 6.70
# Mean - Time taken: 2.88 seconds
# Results saved to results.xlsx file
