# %% [markdown]
# # Importing Libraries for Data Engineering

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading Dataset

# %%
sensors_data = pd.read_excel('PL_scattered_customized.xlsx', header=None)

# %%
sensors_data
# Out:
#                0           1           2           3           4           5  \
# 0     107.054538  129.781007   84.261550  111.505422  133.051552  144.840172
# 1      96.660088  131.162733   89.729450  122.185828  124.954489  142.531844
# 2     102.206838  127.171002   71.340799  121.185648  131.482697  148.874547
# 3      95.445118  125.459953   88.801906  116.871027  124.583238  139.240308
# 4     102.463012  130.965909   82.096225  121.002333  126.955355  145.234341
# ...          ...         ...         ...         ...         ...         ...
# 2438  132.754981  114.550086  112.018932   69.517026  150.835001  125.316425
# 2439  126.661521  109.701274  108.486032   72.587456  160.679014  129.522800
# 2440  126.465696  112.073561  111.113704   77.490180  149.537669  128.051940
# 2441  126.477809  115.729218   99.562322   81.972027  149.712756  138.928011
# 2442  123.262448  109.683449   96.672728   80.982757  145.873760  132.424032
#
#                6           7
# 0     109.271683  128.989901
# 1     102.738888  129.788691
# 2     119.657129  134.605286
# 3     103.341606  132.680343
# 4     119.308555  133.314447
# ...          ...         ...
# 2438  124.263461  101.676050
# 2439  140.643100   99.016397
# 2440  133.995351  102.493823
# 2441  129.759599   97.726909
# 2442  134.932294  100.654557
#
# [2443 rows x 8 columns]

# %%
position_data = pd.read_excel('real x-y-z positions of 2443 locations.xlsx', header=None)

# %%
position_data
# Out:
#               0          1      2
# 0    -45.581275  30.239368 -60.00
# 1    -45.188830  30.181623 -59.96
# 2    -44.791865  30.131806 -59.92
# 3    -44.390422  30.089935 -59.88
# 4    -43.984540  30.056029 -59.84
# ...         ...        ...    ...
# 2438 -59.939858  51.788725  37.52
# 2439 -59.963718  51.389997  37.56
# 2440 -59.981583  50.990713  37.60
# 2441 -59.993448  50.591032  37.64
# 2442 -59.999315  50.191116  37.68
#
# [2443 rows x 3 columns]

# %% [markdown]
# # Data Engineering

# %% [markdown]
# ### Sensors Data -- Labeling Columns

# %%
Sensors_Number_of_Columns = sensors_data.shape[1]

# %%
Sensors_columns = ["sensor" + str(x) for x in range(1,Sensors_Number_of_Columns + 1)]
sensors_data.columns = (Sensors_columns)

# %%
sensors_data
# Out:
#          sensor1     sensor2     sensor3     sensor4     sensor5     sensor6  \
# 0     107.054538  129.781007   84.261550  111.505422  133.051552  144.840172
# 1      96.660088  131.162733   89.729450  122.185828  124.954489  142.531844
# 2     102.206838  127.171002   71.340799  121.185648  131.482697  148.874547
# 3      95.445118  125.459953   88.801906  116.871027  124.583238  139.240308
# 4     102.463012  130.965909   82.096225  121.002333  126.955355  145.234341
# ...          ...         ...         ...         ...         ...         ...
# 2438  132.754981  114.550086  112.018932   69.517026  150.835001  125.316425
# 2439  126.661521  109.701274  108.486032   72.587456  160.679014  129.522800
# 2440  126.465696  112.073561  111.113704   77.490180  149.537669  128.051940
# 2441  126.477809  115.729218   99.562322   81.972027  149.712756  138.928011
# 2442  123.262448  109.683449   96.672728   80.982757  145.873760  132.424032
#
#          sensor7     sensor8
# 0     109.271683  128.989901
# 1     102.738888  129.788691
# 2     119.657129  134.605286
# 3     103.341606  132.680343
# 4     119.308555  133.314447
# ...          ...         ...
# 2438  124.263461  101.676050
# 2439  140.643100   99.016397
# 2440  133.995351  102.493823
# 2441  129.759599   97.726909
# 2442  134.932294  100.654557
#
# [2443 rows x 8 columns]

# %% [markdown]
# ### Converting to Pandas Dataframe

# %%
sensors_data = pd.DataFrame(sensors_data)

# %% [markdown]
# ### Position Data -- Labeling Columns

# %%
position_data.columns = ['Pos X', 'Pos Y', 'Pos Z']

# %%
position_data
# Out:
#           Pos X      Pos Y  Pos Z
# 0    -45.581275  30.239368 -60.00
# 1    -45.188830  30.181623 -59.96
# 2    -44.791865  30.131806 -59.92
# 3    -44.390422  30.089935 -59.88
# 4    -43.984540  30.056029 -59.84
# ...         ...        ...    ...
# 2438 -59.939858  51.788725  37.52
# 2439 -59.963718  51.389997  37.56
# 2440 -59.981583  50.990713  37.60
# 2441 -59.993448  50.591032  37.64
# 2442 -59.999315  50.191116  37.68
#
# [2443 rows x 3 columns]

# %% [markdown]
# ### Converting to Pandas Dataframe

# %%
position_data = pd.DataFrame(position_data)

# %% [markdown]
# ### Concatenating Dataframes

# %%
raw_data = pd.concat([sensors_data, position_data], axis = 1)
raw_data
# Out:
#          sensor1     sensor2     sensor3     sensor4     sensor5     sensor6  \
# 0     107.054538  129.781007   84.261550  111.505422  133.051552  144.840172
# 1      96.660088  131.162733   89.729450  122.185828  124.954489  142.531844
# 2     102.206838  127.171002   71.340799  121.185648  131.482697  148.874547
# 3      95.445118  125.459953   88.801906  116.871027  124.583238  139.240308
# 4     102.463012  130.965909   82.096225  121.002333  126.955355  145.234341
# ...          ...         ...         ...         ...         ...         ...
# 2438  132.754981  114.550086  112.018932   69.517026  150.835001  125.316425
# 2439  126.661521  109.701274  108.486032   72.587456  160.679014  129.522800
# 2440  126.465696  112.073561  111.113704   77.490180  149.537669  128.051940
# 2441  126.477809  115.729218   99.562322   81.972027  149.712756  138.928011
# 2442  123.262448  109.683449   96.672728   80.982757  145.873760  132.424032
#
#          sensor7     sensor8      Pos X      Pos Y  Pos Z
# 0     109.271683  128.989901 -45.581275  30.239368 -60.00
# 1     102.738888  129.788691 -45.188830  30.181623 -59.96
# 2     119.657129  134.605286 -44.791865  30.131806 -59.92
# 3     103.341606  132.680343 -44.390422  30.089935 -59.88
# 4     119.308555  133.314447 -43.984540  30.056029 -59.84
# ...          ...         ...        ...        ...    ...
# 2438  124.263461  101.676050 -59.939858  51.788725  37.52
# 2439  140.643100   99.016397 -59.963718  51.389997  37.56
# 2440  133.995351  102.493823 -59.981583  50.990713  37.60
# 2441  129.759599   97.726909 -59.993448  50.591032  37.64
# 2442  134.932294  100.654557 -59.999315  50.191116  37.68
#
# [2443 rows x 11 columns]

# %% [markdown]
# # Split the data into training and testing sets

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(sensors_data, position_data, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#          sensor1     sensor2     sensor3     sensor4     sensor5     sensor6  \
# 233   151.887410  149.242048  106.822383  134.137776  109.394791  130.304120
# 433   123.002834  136.304453   79.764416  109.094642  136.804745  149.118391
# 1430  145.802309  134.553748  117.792401  106.725307  128.761971  126.840838
# 307   125.960288  150.682128  116.394626  125.555828  103.492835  125.750813
# 2197  144.805027  113.569133  133.307673  102.339469  122.722052  101.320159
# ...          ...         ...         ...         ...         ...         ...
# 1638  127.060484  118.639607  117.191304  100.625479  132.800370  117.032157
# 1095  123.518122  130.183019   83.256027  101.274738  137.773932  135.674681
# 1130  121.515707  127.068566   78.653224   92.028888  138.128417  147.761210
# 1294  117.944416  119.540373   94.438163  100.019423  126.311213  132.643445
# 860   141.072830  150.158158  120.345584  124.097166  114.190252  117.334765
#
#          sensor7     sensor8
# 233    73.459793  107.738583
# 433   105.424362  115.520341
# 1430   84.764104   91.852702
# 307    83.101862  101.730550
# 2197  111.961153   80.694739
# ...          ...         ...
# 1638  100.643994   97.605119
# 1095  107.271760  113.644583
# 1130  117.909430  112.867798
# 1294  116.357880  106.959753
# 860    83.246429   93.989765
#
# [1954 rows x 8 columns]

# %%
y_train
# Out:
#           Pos X      Pos Y  Pos Z
# 233   59.678117  54.115562 -50.68
# 433  -19.191177  62.122007 -42.68
# 1430  45.890531  69.708995  -2.80
# 307   48.255475  30.881811 -47.72
# 2197  46.396180  30.387490  27.88
# ...         ...        ...    ...
# 1638  11.378450  42.552019   5.52
# 1095 -36.900143  69.397796 -16.20
# 1130 -50.886002  67.974162 -14.80
# 1294 -28.195387  33.407817  -8.24
# 860   59.591095  54.630197 -25.60
#
# [1954 rows x 3 columns]

# %% [markdown]
# # Vanilla Machine Learning

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.ensemble import GradientBoostingRegressor

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, median_absolute_error
from sklearn.metrics import explained_variance_score, max_error, mean_squared_log_error

# %%
# Initialize the models
models = [LinearRegression(), DecisionTreeRegressor(), RandomForestRegressor(), KNeighborsRegressor(),  XGBRegressor()]

# %%
# Train and evaluate each model
for model in models:
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(type(model).__name__)
    print("Accuracy:", model.score(X_test, y_test))
    print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
    print("R2 Score:", r2_score(y_test, y_pred))
    print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
    print("Median Absolute Error:", median_absolute_error(y_test, y_pred))
    print("Explained Variance Score:", explained_variance_score(y_test, y_pred))
    print("="*100)
# Out:
# LinearRegression
# Accuracy: 0.9145211592811092
# Mean Squared Error: 42.95059848593015
# R2 Score: 0.9145211592811092
# Mean Absolute Error: 5.14824035708518
# Median Absolute Error: 4.289879974129444
# Explained Variance Score: 0.9145491981976065
# ====================================================================================================
# DecisionTreeRegressor
# Accuracy: 0.7773651881701532
# Mean Squared Error: 111.74838652767642
# R2 Score: 0.7773651881701532
# Mean Absolute Error: 6.929339906505888
# Median Absolute Error: 3.957433372964163
# Explained Variance Score: 0.7775511873179823
# ====================================================================================================
# RandomForestRegressor
# Accuracy: 0.9146582683531149
# Mean Squared Error: 42.02940025396355
# R2 Score: 0.9146582683531149
# Mean Absolute Error: 4.824753717175966
# Median Absolute Error: 3.5263868821260087
# Explained Variance Score: 0.9147652663610119
# ====================================================================================================
# KNeighborsRegressor
# Accuracy: 0.9315221106289918
# Mean Squared Error: 35.95235757954898
# R2 Score: 0.9315221106289918
# Mean Absolute Error: 4.129404963799409
# Median Absolute Error: 2.6735267829103884
# Explained Variance Score: 0.9319300827722247
# ====================================================================================================
# XGBRegressor
# Accuracy: 0.9038877935452064
# Mean Squared Error: 49.0157487020928
# R2 Score: 0.9038877935452064
# Mean Absolute Error: 5.231304083213949
# Median Absolute Error: 3.9681198076822866
# Explained Variance Score: 0.9039610504079492
# ====================================================================================================

# %%
# Evaluate each model
for model in models:
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(type(model).__name__, " accuracy: ", model.score(X_test, y_test))
    fig, ax = plt.subplots()
    ax.scatter(y_test, y_pred, edgecolors=(0, 0, 0))
    ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
    ax.set_xlabel('Actual')
    ax.set_ylabel('Predicted')
    plt.show()
# Out:
# LinearRegression  accuracy:  0.9145211592811092
# DecisionTreeRegressor  accuracy:  0.7851994073854911
# RandomForestRegressor  accuracy:  0.9152392278651988
# KNeighborsRegressor  accuracy:  0.9315221106289918
# XGBRegressor  accuracy:  0.9038877935452064

# %% [markdown]
# # Time Calculations

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, median_absolute_error, explained_variance_score
import time

# Train and evaluate each model
for model in models:
    start_time = time.time()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    end_time = time.time()
    
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    
    print(type(model).__name__)
    print("Accuracy:", model.score(X_test, y_test))
    print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
    print("Root Mean Squared Error:", rmse)
    print("R2 Score:", r2_score(y_test, y_pred))
    print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
    print("Median Absolute Error:", median_absolute_error(y_test, y_pred))
    print("Explained Variance Score:", explained_variance_score(y_test, y_pred))
    print("Time taken:", end_time - start_time)
    print("="*100)
# Out:
# LinearRegression
# Accuracy: 0.9145211592811092
# Mean Squared Error: 42.95059848593015
# Root Mean Squared Error: 6.530086309898432
# R2 Score: 0.9145211592811092
# Mean Absolute Error: 5.14824035708518
# Median Absolute Error: 4.289879974129444
# Explained Variance Score: 0.9145491981976065
# Time taken: 0.003499746322631836
# ====================================================================================================
# DecisionTreeRegressor
# Accuracy: 0.7716332291607921
# Mean Squared Error: 115.8551310800995
# Root Mean Squared Error: 10.730213178518532
# R2 Score: 0.7716332291607921
# Mean Absolute Error: 6.962369310015205
# Median Absolute Error: 3.7455990204147995
# Explained Variance Score: 0.771692959353942
# Time taken: 0.012002229690551758
# ====================================================================================================
# RandomForestRegressor
# Accuracy: 0.9147791972374257
# Mean Squared Error: 41.61934333868561
# Root Mean Squared Error: 6.438388979456437
# R2 Score: 0.9147791972374257
# Mean Absolute Error: 4.796260871238176
# Median Absolute Error: 3.4337529261166693
# Explained Variance Score: 0.9148540297903079
# Time taken: 0.5970461368560791
# ====================================================================================================
# KNeighborsRegressor
# Accuracy: 0.9315221106289918
# Mean Squared Error: 35.95235757954898
# Root Mean Squared Error: 5.94447973193659
# R2 Score: 0.9315221106289918
# Mean Absolute Error: 4.129404963799409
# Median Absolute Error: 2.6735267829103884
# Explained Variance Score: 0.9319300827722247
# Time taken: 0.0060002803802490234
# ====================================================================================================
# XGBRegressor
# Accuracy: 0.9038877935452064
# Mean Squared Error: 49.0157487020928
# Root Mean Squared Error: 6.977395406266685
# R2 Score: 0.9038877935452064
# Mean Absolute Error: 5.231304083213949
# Median Absolute Error: 3.9681198076822866
# Explained Variance Score: 0.9039610504079492
# Time taken: 0.2520146369934082
# ====================================================================================================

# %% [markdown]
# # Cross Validation

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score, mean_absolute_error
import time


X = sensors_data
y = position_data

#Define models
models = [LinearRegression(), DecisionTreeRegressor(), RandomForestRegressor(), KNeighborsRegressor(), XGBRegressor()]

#Define k-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

#Train and evaluate each model using k-fold cross-validation
for model in models:
    # Evaluate the performance of the model using k-fold cross-validation
    scores_mse = []
    scores_mae = []
    scores_rmse = []
    times = []
    for i, (train_index, test_index) in enumerate(kfold.split(X)):
        start_time = time.time()
        
        X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[test_index]
        y_train_fold, y_val_fold = y.iloc[train_index], y.iloc[test_index]
        model.fit(X_train_fold, y_train_fold)
        y_pred_fold = model.predict(X_val_fold)
        
        
        mse = mean_squared_error(y_val_fold, y_pred_fold)
        mae = mean_absolute_error(y_val_fold, y_pred_fold)
        rmse = np.sqrt(mse)
        end_time = time.time()
        time_taken = end_time - start_time
        scores_mse.append(mse)
        scores_mae.append(mae)
        scores_rmse.append(rmse)
        times.append(time_taken)
        print(f"Model: {type(model).__name__}")
        print(f"Fold {i+1} - Mean Squared Error (MSE): {mse:.2f}")
        print(f"Fold {i+1} - Mean Absolute Error (MAE): {mae:.2f}")
        print(f"Fold {i+1} - Root Mean Squared Error (RMSE): {rmse:.2f}")
        print(f"Fold {i+1} - Time taken: {time_taken:.2f} seconds")
    
    # Calculate mean time and results for all the folds
    mean_mse = np.mean(scores_mse)
    mean_mae = np.mean(scores_mae)
    mean_rmse = np.mean(scores_rmse)
    mean_time = np.mean(times)

    # Print the mean results of the folds
    print(f"Mean MSE: {mean_mse:.2f}")
    print(f"Mean MAE: {mean_mae:.2f}")
    print(f"Mean RMSE: {mean_rmse:.2f}")
    print(f"Mean time: {mean_time:.2f} seconds")
    print("-" * 50)
# Out:
# Model: LinearRegression
# Fold 1 - Mean Squared Error (MSE): 42.95
# Fold 1 - Mean Absolute Error (MAE): 5.15
# Fold 1 - Root Mean Squared Error (RMSE): 6.55
# Fold 1 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 2 - Mean Squared Error (MSE): 46.14
# Fold 2 - Mean Absolute Error (MAE): 5.39
# Fold 2 - Root Mean Squared Error (RMSE): 6.79
# Fold 2 - Time taken: 0.00 seconds
# Model: LinearRegression
# Fold 3 - Mean Squared Error (MSE): 45.37
# Fold 3 - Mean Absolute Error (MAE): 5.36
# Fold 3 - Root Mean Squared Error (RMSE): 6.74
# Fold 3 - Time taken: 0.00 seconds
# Model: LinearRegression
# Fold 4 - Mean Squared Error (MSE): 42.84
# Fold 4 - Mean Absolute Error (MAE): 5.25
# Fold 4 - Root Mean Squared Error (RMSE): 6.54
# Fold 4 - Time taken: 0.00 seconds
# Model: LinearRegression
# Fold 5 - Mean Squared Error (MSE): 43.49
# Fold 5 - Mean Absolute Error (MAE): 5.24
# Fold 5 - Root Mean Squared Error (RMSE): 6.59
# Fold 5 - Time taken: 0.00 seconds
# Mean MSE: 44.16
# Mean MAE: 5.28
# Mean RMSE: 6.64
# Mean time: 0.00 seconds
# --------------------------------------------------
# Model: DecisionTreeRegressor
# Fold 1 - Mean Squared Error (MSE): 111.84
# Fold 1 - Mean Absolute Error (MAE): 6.84
# Fold 1 - Root Mean Squared Error (RMSE): 10.58
# Fold 1 - Time taken: 0.01 seconds
# Model: DecisionTreeRegressor
# Fold 2 - Mean Squared Error (MSE): 109.16
# Fold 2 - Mean Absolute Error (MAE): 6.78
# Fold 2 - Root Mean Squared Error (RMSE): 10.45
# Fold 2 - Time taken: 0.01 seconds
# Model: DecisionTreeRegressor
# Fold 3 - Mean Squared Error (MSE): 127.15
# Fold 3 - Mean Absolute Error (MAE): 7.28
# Fold 3 - Root Mean Squared Error (RMSE): 11.28
# Fold 3 - Time taken: 0.01 seconds
# Model: DecisionTreeRegressor
# Fold 4 - Mean Squared Error (MSE): 116.20
# Fold 4 - Mean Absolute Error (MAE): 6.99
# Fold 4 - Root Mean Squared Error (RMSE): 10.78
# Fold 4 - Time taken: 0.01 seconds
# Model: DecisionTreeRegressor
# Fold 5 - Mean Squared Error (MSE): 112.74
# Fold 5 - Mean Absolute Error (MAE): 6.72
# Fold 5 - Root Mean Squared Error (RMSE): 10.62
# Fold 5 - Time taken: 0.01 seconds
# Mean MSE: 115.42
# Mean MAE: 6.92
# Mean RMSE: 10.74
# Mean time: 0.01 seconds
# --------------------------------------------------
# Model: RandomForestRegressor
# Fold 1 - Mean Squared Error (MSE): 42.55
# Fold 1 - Mean Absolute Error (MAE): 4.83
# Fold 1 - Root Mean Squared Error (RMSE): 6.52
# Fold 1 - Time taken: 0.58 seconds
# Model: RandomForestRegressor
# Fold 2 - Mean Squared Error (MSE): 41.54
# Fold 2 - Mean Absolute Error (MAE): 4.82
# Fold 2 - Root Mean Squared Error (RMSE): 6.44
# Fold 2 - Time taken: 0.59 seconds
# Model: RandomForestRegressor
# Fold 3 - Mean Squared Error (MSE): 44.01
# Fold 3 - Mean Absolute Error (MAE): 4.97
# Fold 3 - Root Mean Squared Error (RMSE): 6.63
# Fold 3 - Time taken: 0.66 seconds
# Model: RandomForestRegressor
# Fold 4 - Mean Squared Error (MSE): 42.18
# Fold 4 - Mean Absolute Error (MAE): 4.94
# Fold 4 - Root Mean Squared Error (RMSE): 6.49
# Fold 4 - Time taken: 0.69 seconds
# Model: RandomForestRegressor
# Fold 5 - Mean Squared Error (MSE): 38.19
# Fold 5 - Mean Absolute Error (MAE): 4.64
# Fold 5 - Root Mean Squared Error (RMSE): 6.18
# Fold 5 - Time taken: 0.90 seconds
# Mean MSE: 41.69
# Mean MAE: 4.84
# Mean RMSE: 6.46
# Mean time: 0.68 seconds
# --------------------------------------------------
# Model: KNeighborsRegressor
# Fold 1 - Mean Squared Error (MSE): 35.95
# Fold 1 - Mean Absolute Error (MAE): 4.13
# Fold 1 - Root Mean Squared Error (RMSE): 6.00
# Fold 1 - Time taken: 0.01 seconds
# Model: KNeighborsRegressor
# Fold 2 - Mean Squared Error (MSE): 36.91
# Fold 2 - Mean Absolute Error (MAE): 4.12
# Fold 2 - Root Mean Squared Error (RMSE): 6.08
# Fold 2 - Time taken: 0.01 seconds
# Model: KNeighborsRegressor
# Fold 3 - Mean Squared Error (MSE): 35.23
# Fold 3 - Mean Absolute Error (MAE): 4.08
# Fold 3 - Root Mean Squared Error (RMSE): 5.94
# Fold 3 - Time taken: 0.01 seconds
# Model: KNeighborsRegressor
# Fold 4 - Mean Squared Error (MSE): 34.47
# Fold 4 - Mean Absolute Error (MAE): 4.16
# Fold 4 - Root Mean Squared Error (RMSE): 5.87
# Fold 4 - Time taken: 0.01 seconds
# Model: KNeighborsRegressor
# Fold 5 - Mean Squared Error (MSE): 30.24
# Fold 5 - Mean Absolute Error (MAE): 3.79
# Fold 5 - Root Mean Squared Error (RMSE): 5.50
# Fold 5 - Time taken: 0.01 seconds
# Mean MSE: 34.56
# Mean MAE: 4.06
# Mean RMSE: 5.88
# Mean time: 0.01 seconds
# --------------------------------------------------
# Model: XGBRegressor
# Fold 1 - Mean Squared Error (MSE): 49.02
# Fold 1 - Mean Absolute Error (MAE): 5.23
# Fold 1 - Root Mean Squared Error (RMSE): 7.00
# Fold 1 - Time taken: 0.64 seconds
# Model: XGBRegressor
# Fold 2 - Mean Squared Error (MSE): 47.10
# Fold 2 - Mean Absolute Error (MAE): 5.07
# Fold 2 - Root Mean Squared Error (RMSE): 6.86
# Fold 2 - Time taken: 0.64 seconds
# Model: XGBRegressor
# Fold 3 - Mean Squared Error (MSE): 49.34
# Fold 3 - Mean Absolute Error (MAE): 5.10
# Fold 3 - Root Mean Squared Error (RMSE): 7.02
# Fold 3 - Time taken: 0.66 seconds
# Model: XGBRegressor
# Fold 4 - Mean Squared Error (MSE): 46.63
# Fold 4 - Mean Absolute Error (MAE): 5.09
# Fold 4 - Root Mean Squared Error (RMSE): 6.83
# Fold 4 - Time taken: 0.69 seconds
# Model: XGBRegressor
# Fold 5 - Mean Squared Error (MSE): 48.08
# Fold 5 - Mean Absolute Error (MAE): 5.11
# Fold 5 - Root Mean Squared Error (RMSE): 6.93
# Fold 5 - Time taken: 1.19 seconds
# Mean MSE: 48.03
# Mean MAE: 5.12
# Mean RMSE: 6.93
# Mean time: 0.76 seconds
# --------------------------------------------------

# %% [markdown]
# # Excel File Conversion

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score, mean_absolute_error
import time


X = sensors_data
y = position_data

# convert numpy array into pandas dataframe
X = pd.DataFrame(X)
y = pd.DataFrame(y)

# Define models
models = [LinearRegression(), DecisionTreeRegressor(), RandomForestRegressor(), KNeighborsRegressor(), XGBRegressor()]

# Define k-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# Create empty dictionary to store the results
results_dict = {
    "Model": [],
    "Fold": [],
    "Mean Squared Error (MSE)": [],
    "Mean Absolute Error (MAE)": [],
    "Root Mean Squared Error (RMSE)": [],
    "Time taken": []
}

# Train and evaluate each model using k-fold cross-validation
for model in models:
    # Evaluate the performance of the model using k-fold cross-validation
    scores_mse = []
    scores_mae = []
    scores_rmse = []
    times = []
    for i, (train_index, test_index) in enumerate(kfold.split(X)):
        start_time = time.time()
        
        X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[test_index]
        y_train_fold, y_val_fold = y.iloc[train_index], y.iloc[test_index]
        model.fit(X_train_fold, y_train_fold)
        y_pred_fold = model.predict(X_val_fold)
        
        
        mse = mean_squared_error(y_val_fold, y_pred_fold)
        mae = mean_absolute_error(y_val_fold, y_pred_fold)
        rmse = np.sqrt(mse)
        end_time = time.time()
        time_taken = end_time - start_time
        scores_mse.append(mse)
        scores_mae.append(mae)
        scores_rmse.append(rmse)
        times.append(time_taken)
        
        # Add the results to the dictionary
        results_dict["Model"].append(type(model).__name__)
        results_dict["Fold"].append(i+1)
        results_dict["Mean Squared Error (MSE)"].append(mse)
        results_dict["Mean Absolute Error (MAE)"].append(mae)
        results_dict["Root Mean Squared Error (RMSE)"].append(rmse)
        results_dict["Time taken"].append(time_taken)
        
        print(f"Model: {type(model).__name__}")
        print(f"Fold {i+1} - Mean Squared Error (MSE): {mse:.2f}")
        print(f"Fold {i+1} - Mean Absolute Error (MAE): {mae:.2f}")
        print(f"Fold {i+1} - Root Mean Squared Error (RMSE): {rmse:.2f}")
        print(f"Fold {i+1} - Time taken: {time_taken:.2f} seconds")
    
    # Calculate mean time and results for all the folds
    mean_mse = np.mean(scores_mse)
    mean_mae = np.mean(scores_mae)
    mean_rmse = np.mean(scores_rmse)
    mean_time = np.mean(times)

    # Add the mean results to the dictionary
    results_dict["Model"].append(type(model).__name__)
    results_dict["Fold"].append("Mean")
    results_dict["Mean Squared Error (MSE)"].append(mean_mse)
    results_dict["Mean Absolute Error (MAE)"].append(mean_mae)
    results_dict["Root Mean Squared Error (RMSE)"].append(mean_rmse)
    results_dict["Time taken"].append(mean_time)

    print(f"Model: {type(model).__name__}")
    print(f"Mean - Mean Squared Error (MSE): {mean_mse:.2f}")
    print(f"Mean - Mean Absolute Error (MAE): {mean_mae:.2f}")
    print(f"Mean - Root Mean Squared Error (RMSE): {mean_rmse:.2f}")
    print(f"Mean - Time taken: {mean_time:.2f} seconds")

    
#Convert the results dictionary into a pandas dataframe
results_df = pd.DataFrame.from_dict(results_dict)

#Save the results to an Excel file
results_df.to_excel("PL_scattered_customized Result.xlsx", index=False)

#Print a message indicating that the results have been saved to a file
print("Results saved to PL_scattered_customized Result.xlsx file")
# Out:
# Model: LinearRegression
# Fold 1 - Mean Squared Error (MSE): 42.95
# Fold 1 - Mean Absolute Error (MAE): 5.15
# Fold 1 - Root Mean Squared Error (RMSE): 6.55
# Fold 1 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 2 - Mean Squared Error (MSE): 46.14
# Fold 2 - Mean Absolute Error (MAE): 5.39
# Fold 2 - Root Mean Squared Error (RMSE): 6.79
# Fold 2 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 3 - Mean Squared Error (MSE): 45.37
# Fold 3 - Mean Absolute Error (MAE): 5.36
# Fold 3 - Root Mean Squared Error (RMSE): 6.74
# Fold 3 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 4 - Mean Squared Error (MSE): 42.84
# Fold 4 - Mean Absolute Error (MAE): 5.25
# Fold 4 - Root Mean Squared Error (RMSE): 6.54
# Fold 4 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 5 - Mean Squared Error (MSE): 43.49
# Fold 5 - Mean Absolute Error (MAE): 5.24
# Fold 5 - Root Mean Squared Error (RMSE): 6.59
# Fold 5 - Time taken: 0.01 seconds
# Model: LinearRegression
# Mean - Mean Squared Error (MSE): 44.16
# Mean - Mean Absolute Error (MAE): 5.28
# Mean - Root Mean Squared Error (RMSE): 6.64
# Mean - Time taken: 0.01 seconds
# Model: DecisionTreeRegressor
# Fold 1 - Mean Squared Error (MSE): 118.06
# Fold 1 - Mean Absolute Error (MAE): 7.06
# Fold 1 - Root Mean Squared Error (RMSE): 10.87
# Fold 1 - Time taken: 0.02 seconds
# Model: DecisionTreeRegressor
# Fold 2 - Mean Squared Error (MSE): 105.79
# Fold 2 - Mean Absolute Error (MAE): 6.72
# Fold 2 - Root Mean Squared Error (RMSE): 10.29
# Fold 2 - Time taken: 0.02 seconds
# Model: DecisionTreeRegressor
# Fold 3 - Mean Squared Error (MSE): 120.61
# Fold 3 - Mean Absolute Error (MAE): 7.16
# Fold 3 - Root Mean Squared Error (RMSE): 10.98
# Fold 3 - Time taken: 0.02 seconds
# Model: DecisionTreeRegressor
# Fold 4 - Mean Squared Error (MSE): 109.79
# Fold 4 - Mean Absolute Error (MAE): 6.83
# Fold 4 - Root Mean Squared Error (RMSE): 10.48
# Fold 4 - Time taken: 0.02 seconds
# Model: DecisionTreeRegressor
# Fold 5 - Mean Squared Error (MSE): 107.78
# Fold 5 - Mean Absolute Error (MAE): 6.58
# Fold 5 - Root Mean Squared Error (RMSE): 10.38
# Fold 5 - Time taken: 0.02 seconds
# Model: DecisionTreeRegressor
# Mean - Mean Squared Error (MSE): 112.41
# Mean - Mean Absolute Error (MAE): 6.87
# Mean - Root Mean Squared Error (RMSE): 10.60
# Mean - Time taken: 0.02 seconds
# Model: RandomForestRegressor
# Fold 1 - Mean Squared Error (MSE): 41.89
# Fold 1 - Mean Absolute Error (MAE): 4.81
# Fold 1 - Root Mean Squared Error (RMSE): 6.47
# Fold 1 - Time taken: 0.95 seconds
# Model: RandomForestRegressor
# Fold 2 - Mean Squared Error (MSE): 42.72
# Fold 2 - Mean Absolute Error (MAE): 4.89
# Fold 2 - Root Mean Squared Error (RMSE): 6.54
# Fold 2 - Time taken: 0.95 seconds
# Model: RandomForestRegressor
# Fold 3 - Mean Squared Error (MSE): 43.25
# Fold 3 - Mean Absolute Error (MAE): 4.92
# Fold 3 - Root Mean Squared Error (RMSE): 6.58
# Fold 3 - Time taken: 0.95 seconds
# Model: RandomForestRegressor
# Fold 4 - Mean Squared Error (MSE): 42.48
# Fold 4 - Mean Absolute Error (MAE): 4.96
# Fold 4 - Root Mean Squared Error (RMSE): 6.52
# Fold 4 - Time taken: 0.92 seconds
# Model: RandomForestRegressor
# Fold 5 - Mean Squared Error (MSE): 37.54
# Fold 5 - Mean Absolute Error (MAE): 4.57
# Fold 5 - Root Mean Squared Error (RMSE): 6.13
# Fold 5 - Time taken: 0.90 seconds
# Model: RandomForestRegressor
# Mean - Mean Squared Error (MSE): 41.57
# Mean - Mean Absolute Error (MAE): 4.83
# Mean - Root Mean Squared Error (RMSE): 6.45
# Mean - Time taken: 0.93 seconds
# Model: KNeighborsRegressor
# Fold 1 - Mean Squared Error (MSE): 35.95
# Fold 1 - Mean Absolute Error (MAE): 4.13
# Fold 1 - Root Mean Squared Error (RMSE): 6.00
# Fold 1 - Time taken: 0.01 seconds
# Model: KNeighborsRegressor
# Fold 2 - Mean Squared Error (MSE): 36.91
# Fold 2 - Mean Absolute Error (MAE): 4.12
# Fold 2 - Root Mean Squared Error (RMSE): 6.08
# Fold 2 - Time taken: 0.01 seconds
# Model: KNeighborsRegressor
# Fold 3 - Mean Squared Error (MSE): 35.23
# Fold 3 - Mean Absolute Error (MAE): 4.08
# Fold 3 - Root Mean Squared Error (RMSE): 5.94
# Fold 3 - Time taken: 0.01 seconds
# Model: KNeighborsRegressor
# Fold 4 - Mean Squared Error (MSE): 34.47
# Fold 4 - Mean Absolute Error (MAE): 4.16
# Fold 4 - Root Mean Squared Error (RMSE): 5.87
# Fold 4 - Time taken: 0.01 seconds
# Model: KNeighborsRegressor
# Fold 5 - Mean Squared Error (MSE): 30.24
# Fold 5 - Mean Absolute Error (MAE): 3.79
# Fold 5 - Root Mean Squared Error (RMSE): 5.50
# Fold 5 - Time taken: 0.01 seconds
# Model: KNeighborsRegressor
# Mean - Mean Squared Error (MSE): 34.56
# Mean - Mean Absolute Error (MAE): 4.06
# Mean - Root Mean Squared Error (RMSE): 5.88
# Mean - Time taken: 0.01 seconds
# Model: XGBRegressor
# Fold 1 - Mean Squared Error (MSE): 49.02
# Fold 1 - Mean Absolute Error (MAE): 5.23
# Fold 1 - Root Mean Squared Error (RMSE): 7.00
# Fold 1 - Time taken: 0.77 seconds
# Model: XGBRegressor
# Fold 2 - Mean Squared Error (MSE): 47.10
# Fold 2 - Mean Absolute Error (MAE): 5.07
# Fold 2 - Root Mean Squared Error (RMSE): 6.86
# Fold 2 - Time taken: 0.78 seconds
# Model: XGBRegressor
# Fold 3 - Mean Squared Error (MSE): 49.34
# Fold 3 - Mean Absolute Error (MAE): 5.10
# Fold 3 - Root Mean Squared Error (RMSE): 7.02
# Fold 3 - Time taken: 0.83 seconds
# Model: XGBRegressor
# Fold 4 - Mean Squared Error (MSE): 46.63
# Fold 4 - Mean Absolute Error (MAE): 5.09
# Fold 4 - Root Mean Squared Error (RMSE): 6.83
# Fold 4 - Time taken: 1.20 seconds
# Model: XGBRegressor
# Fold 5 - Mean Squared Error (MSE): 48.08
# Fold 5 - Mean Absolute Error (MAE): 5.11
# Fold 5 - Root Mean Squared Error (RMSE): 6.93
# Fold 5 - Time taken: 1.17 seconds
# Model: XGBRegressor
# Mean - Mean Squared Error (MSE): 48.03
# Mean - Mean Absolute Error (MAE): 5.12
# Mean - Root Mean Squared Error (RMSE): 6.93
# Mean - Time taken: 0.95 seconds
# Results saved to PL_scattered_customized Result.xlsx file
