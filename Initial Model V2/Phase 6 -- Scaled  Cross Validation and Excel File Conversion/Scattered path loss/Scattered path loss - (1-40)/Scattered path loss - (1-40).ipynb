# 1130  141.828877  107.494969  107.256587
# 1294  127.457323  112.265567   99.373877
# 860   109.837421   73.086046   71.315165
#
# [1954 rows x 40 columns]

# %%
y_train
# Out:
#           Pos X      Pos Y  Pos Z
# 233   59.678117  54.115562 -50.68
# 433  -19.191177  62.122007 -42.68
# 1430  45.890531  69.708995  -2.80
# 307   48.255475  30.881811 -47.72
# 2197  46.396180  30.387490  27.88
# ...         ...        ...    ...
# 1638  11.378450  42.552019   5.52
# 1095 -36.900143  69.397796 -16.20
# 1130 -50.886002  67.974162 -14.80
# 1294 -28.195387  33.407817  -8.24
# 860   59.591095  54.630197 -25.60
#
# [1954 rows x 3 columns]

# %% [markdown]
# # Machine Learning

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.ensemble import GradientBoostingRegressor

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, median_absolute_error
from sklearn.metrics import explained_variance_score, max_error, mean_squared_log_error

# %%
# Initialize the models
models = [LinearRegression(), DecisionTreeRegressor(), RandomForestRegressor(), KNeighborsRegressor(),  XGBRegressor()]

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, median_absolute_error, explained_variance_score
import time

# Train and evaluate each model
for model in models:
    start_time = time.time()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    end_time = time.time()
    
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    
    print(type(model).__name__)
    print("Accuracy:", model.score(X_test, y_test))
    print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
    print("Root Mean Squared Error:", rmse)
    print("R2 Score:", r2_score(y_test, y_pred))
    print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
    print("Median Absolute Error:", median_absolute_error(y_test, y_pred))
    print("Explained Variance Score:", explained_variance_score(y_test, y_pred))
    print("Time taken:", end_time - start_time)
    print("="*100)
# Out:
# LinearRegression
# Accuracy: 0.9796327073326473
# Mean Squared Error: 8.98250157466733
# Root Mean Squared Error: 2.9945943520759886
# R2 Score: 0.9796327073326473
# Mean Absolute Error: 2.394778524642001
# Median Absolute Error: 1.9816366177918876
# Explained Variance Score: 0.9796520584718859
# Time taken: 0.00599980354309082
# ====================================================================================================
# DecisionTreeRegressor
# Accuracy: 0.796382306550283
# Mean Squared Error: 96.30035289501795
# Root Mean Squared Error: 9.78753163809049
# R2 Score: 0.796382306550283
# Mean Absolute Error: 6.25770298873367
# Median Absolute Error: 3.2866823782274017
# Explained Variance Score: 0.7975899230167096
# Time taken: 0.03749990463256836
# ====================================================================================================
# RandomForestRegressor
# Accuracy: 0.9605102197888948
# Mean Squared Error: 18.26894102979345
# Root Mean Squared Error: 4.272358261022798
# R2 Score: 0.9605102197888948
# Mean Absolute Error: 3.3989162754414894
# Median Absolute Error: 2.918096315007382
# Explained Variance Score: 0.9607089999139279
# Time taken: 2.4269959926605225
# ====================================================================================================
# KNeighborsRegressor
# Accuracy: 0.9878893973623333
# Mean Squared Error: 5.835250653919385
# Root Mean Squared Error: 2.2632244387894613
# R2 Score: 0.9878893973623333
# Mean Absolute Error: 1.5751402919931126
# Median Absolute Error: 1.1387153224599078
# Explained Variance Score: 0.9879105022012413
# Time taken: 0.05050086975097656
# ====================================================================================================
# XGBRegressor
# Accuracy: 0.9601304403628221
# Mean Squared Error: 20.44830748742154
# Root Mean Squared Error: 4.504017458110024
# R2 Score: 0.9601304403628221
# Mean Absolute Error: 3.316167856094045
# Median Absolute Error: 2.3515920192643898
# Explained Variance Score: 0.9603161974185944
# Time taken: 0.4869992733001709
# ====================================================================================================

# %% [markdown]
# # Cross Validation

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score, mean_absolute_error
import time


X = sensors_data
y = position_data

#Define models
models = [LinearRegression(), DecisionTreeRegressor(), RandomForestRegressor(), KNeighborsRegressor(), XGBRegressor()]

#Define k-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

#Train and evaluate each model using k-fold cross-validation
for model in models:
    # Evaluate the performance of the model using k-fold cross-validation
    scores_mse = []
    scores_mae = []
    scores_rmse = []
    times = []
    for i, (train_index, test_index) in enumerate(kfold.split(X)):
        start_time = time.time()
        
        X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[test_index]
        y_train_fold, y_val_fold = y.iloc[train_index], y.iloc[test_index]
        model.fit(X_train_fold, y_train_fold)
        y_pred_fold = model.predict(X_val_fold)
        
        
        mse = mean_squared_error(y_val_fold, y_pred_fold)
        mae = mean_absolute_error(y_val_fold, y_pred_fold)
        rmse = np.sqrt(mse)
        end_time = time.time()
        time_taken = end_time - start_time
        scores_mse.append(mse)
        scores_mae.append(mae)
        scores_rmse.append(rmse)
        times.append(time_taken)
        print(f"Model: {type(model).__name__}")
        print(f"Fold {i+1} - Mean Squared Error (MSE): {mse:.2f}")
        print(f"Fold {i+1} - Mean Absolute Error (MAE): {mae:.2f}")
        print(f"Fold {i+1} - Root Mean Squared Error (RMSE): {rmse:.2f}")
        print(f"Fold {i+1} - Time taken: {time_taken:.2f} seconds")
    
    # Calculate mean time and results for all the folds
    mean_mse = np.mean(scores_mse)
    mean_mae = np.mean(scores_mae)
    mean_rmse = np.mean(scores_rmse)
    mean_time = np.mean(times)

    # Print the mean results of the folds
    print(f"Mean MSE: {mean_mse:.2f}")
    print(f"Mean MAE: {mean_mae:.2f}")
    print(f"Mean RMSE: {mean_rmse:.2f}")
    print(f"Mean time: {mean_time:.2f} seconds")
    print("-" * 50)
# Out:
# Model: LinearRegression
# Fold 1 - Mean Squared Error (MSE): 8.98
# Fold 1 - Mean Absolute Error (MAE): 2.39
# Fold 1 - Root Mean Squared Error (RMSE): 3.00
# Fold 1 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 2 - Mean Squared Error (MSE): 9.36
# Fold 2 - Mean Absolute Error (MAE): 2.43
# Fold 2 - Root Mean Squared Error (RMSE): 3.06
# Fold 2 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 3 - Mean Squared Error (MSE): 8.96
# Fold 3 - Mean Absolute Error (MAE): 2.39
# Fold 3 - Root Mean Squared Error (RMSE): 2.99
# Fold 3 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 4 - Mean Squared Error (MSE): 9.32
# Fold 4 - Mean Absolute Error (MAE): 2.44
# Fold 4 - Root Mean Squared Error (RMSE): 3.05
# Fold 4 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 5 - Mean Squared Error (MSE): 9.43
# Fold 5 - Mean Absolute Error (MAE): 2.44
# Fold 5 - Root Mean Squared Error (RMSE): 3.07
# Fold 5 - Time taken: 0.01 seconds
# Mean MSE: 9.21
# Mean MAE: 2.42
# Mean RMSE: 3.04
# Mean time: 0.01 seconds
# --------------------------------------------------
# Model: DecisionTreeRegressor
# Fold 1 - Mean Squared Error (MSE): 98.07
# Fold 1 - Mean Absolute Error (MAE): 6.30
# Fold 1 - Root Mean Squared Error (RMSE): 9.90
# Fold 1 - Time taken: 0.05 seconds
# Model: DecisionTreeRegressor
# Fold 2 - Mean Squared Error (MSE): 83.92
# Fold 2 - Mean Absolute Error (MAE): 5.69
# Fold 2 - Root Mean Squared Error (RMSE): 9.16
# Fold 2 - Time taken: 0.04 seconds
# Model: DecisionTreeRegressor
# Fold 3 - Mean Squared Error (MSE): 85.85
# Fold 3 - Mean Absolute Error (MAE): 5.82
# Fold 3 - Root Mean Squared Error (RMSE): 9.27
# Fold 3 - Time taken: 0.04 seconds
# Model: DecisionTreeRegressor
# Fold 4 - Mean Squared Error (MSE): 95.95
# Fold 4 - Mean Absolute Error (MAE): 6.39
# Fold 4 - Root Mean Squared Error (RMSE): 9.80
# Fold 4 - Time taken: 0.04 seconds
# Model: DecisionTreeRegressor
# Fold 5 - Mean Squared Error (MSE): 98.35
# Fold 5 - Mean Absolute Error (MAE): 6.11
# Fold 5 - Root Mean Squared Error (RMSE): 9.92
# Fold 5 - Time taken: 0.04 seconds
# Mean MSE: 92.43
# Mean MAE: 6.06
# Mean RMSE: 9.61
# Mean time: 0.04 seconds
# --------------------------------------------------
# Model: RandomForestRegressor
# Fold 1 - Mean Squared Error (MSE): 18.57
# Fold 1 - Mean Absolute Error (MAE): 3.44
# Fold 1 - Root Mean Squared Error (RMSE): 4.31
# Fold 1 - Time taken: 2.39 seconds
# Model: RandomForestRegressor
# Fold 2 - Mean Squared Error (MSE): 16.56
# Fold 2 - Mean Absolute Error (MAE): 3.28
# Fold 2 - Root Mean Squared Error (RMSE): 4.07
# Fold 2 - Time taken: 3.52 seconds
# Model: RandomForestRegressor
# Fold 3 - Mean Squared Error (MSE): 17.98
# Fold 3 - Mean Absolute Error (MAE): 3.41
# Fold 3 - Root Mean Squared Error (RMSE): 4.24
# Fold 3 - Time taken: 3.54 seconds
# Model: RandomForestRegressor
# Fold 4 - Mean Squared Error (MSE): 19.59
# Fold 4 - Mean Absolute Error (MAE): 3.54
# Fold 4 - Root Mean Squared Error (RMSE): 4.43
# Fold 4 - Time taken: 3.55 seconds
# Model: RandomForestRegressor
# Fold 5 - Mean Squared Error (MSE): 17.93
# Fold 5 - Mean Absolute Error (MAE): 3.37
# Fold 5 - Root Mean Squared Error (RMSE): 4.23
# Fold 5 - Time taken: 3.59 seconds
# Mean MSE: 18.12
# Mean MAE: 3.41
# Mean RMSE: 4.26
# Mean time: 3.32 seconds
# --------------------------------------------------
# Model: KNeighborsRegressor
# Fold 1 - Mean Squared Error (MSE): 5.84
# Fold 1 - Mean Absolute Error (MAE): 1.58
# Fold 1 - Root Mean Squared Error (RMSE): 2.42
# Fold 1 - Time taken: 0.05 seconds
# Model: KNeighborsRegressor
# Fold 2 - Mean Squared Error (MSE): 5.87
# Fold 2 - Mean Absolute Error (MAE): 1.59
# Fold 2 - Root Mean Squared Error (RMSE): 2.42
# Fold 2 - Time taken: 0.05 seconds
# Model: KNeighborsRegressor
# Fold 3 - Mean Squared Error (MSE): 6.18
# Fold 3 - Mean Absolute Error (MAE): 1.64
# Fold 3 - Root Mean Squared Error (RMSE): 2.49
# Fold 3 - Time taken: 0.05 seconds
# Model: KNeighborsRegressor
# Fold 4 - Mean Squared Error (MSE): 6.11
# Fold 4 - Mean Absolute Error (MAE): 1.63
# Fold 4 - Root Mean Squared Error (RMSE): 2.47
# Fold 4 - Time taken: 0.05 seconds
# Model: KNeighborsRegressor
# Fold 5 - Mean Squared Error (MSE): 6.72
# Fold 5 - Mean Absolute Error (MAE): 1.69
# Fold 5 - Root Mean Squared Error (RMSE): 2.59
# Fold 5 - Time taken: 0.05 seconds
# Mean MSE: 6.14
# Mean MAE: 1.62
# Mean RMSE: 2.48
# Mean time: 0.05 seconds
# --------------------------------------------------
# Model: XGBRegressor
# Fold 1 - Mean Squared Error (MSE): 20.45
# Fold 1 - Mean Absolute Error (MAE): 3.32
# Fold 1 - Root Mean Squared Error (RMSE): 4.52
# Fold 1 - Time taken: 6.92 seconds
# Model: XGBRegressor
# Fold 2 - Mean Squared Error (MSE): 21.52
# Fold 2 - Mean Absolute Error (MAE): 3.36
# Fold 2 - Root Mean Squared Error (RMSE): 4.64
# Fold 2 - Time taken: 6.72 seconds
# Model: XGBRegressor
# Fold 3 - Mean Squared Error (MSE): 20.31
# Fold 3 - Mean Absolute Error (MAE): 3.33
# Fold 3 - Root Mean Squared Error (RMSE): 4.51
# Fold 3 - Time taken: 6.70 seconds
# Model: XGBRegressor
# Fold 4 - Mean Squared Error (MSE): 21.78
# Fold 4 - Mean Absolute Error (MAE): 3.38
# Fold 4 - Root Mean Squared Error (RMSE): 4.67
# Fold 4 - Time taken: 6.75 seconds
# Model: XGBRegressor
# Fold 5 - Mean Squared Error (MSE): 22.19
# Fold 5 - Mean Absolute Error (MAE): 3.43
# Fold 5 - Root Mean Squared Error (RMSE): 4.71
# Fold 5 - Time taken: 7.73 seconds
# Mean MSE: 21.25
# Mean MAE: 3.36
# Mean RMSE: 4.61
# Mean time: 6.96 seconds
# --------------------------------------------------

# %% [markdown]
# # Excel File Conversion

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score, mean_absolute_error
import time


X = sensors_data
y = position_data

# convert numpy array into pandas dataframe
X = pd.DataFrame(X)
y = pd.DataFrame(y)

# Define models
models = [LinearRegression(), DecisionTreeRegressor(), RandomForestRegressor(), KNeighborsRegressor(), XGBRegressor()]

# Define k-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# Create empty dictionary to store the results
results_dict = {
    "Model": [],
    "Fold": [],
    "Mean Squared Error (MSE)": [],
    "Mean Absolute Error (MAE)": [],
    "Root Mean Squared Error (RMSE)": [],
    "Time taken": []
}

# Train and evaluate each model using k-fold cross-validation
for model in models:
    # Evaluate the performance of the model using k-fold cross-validation
    scores_mse = []
    scores_mae = []
    scores_rmse = []
    times = []
    for i, (train_index, test_index) in enumerate(kfold.split(X)):
        start_time = time.time()
        
        X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[test_index]
        y_train_fold, y_val_fold = y.iloc[train_index], y.iloc[test_index]
        model.fit(X_train_fold, y_train_fold)
        y_pred_fold = model.predict(X_val_fold)
        
        
        mse = mean_squared_error(y_val_fold, y_pred_fold)
        mae = mean_absolute_error(y_val_fold, y_pred_fold)
        rmse = np.sqrt(mse)
        end_time = time.time()
        time_taken = end_time - start_time
        scores_mse.append(mse)
        scores_mae.append(mae)
        scores_rmse.append(rmse)
        times.append(time_taken)
        
        # Add the results to the dictionary
        results_dict["Model"].append(type(model).__name__)
        results_dict["Fold"].append(i+1)
        results_dict["Mean Squared Error (MSE)"].append(mse)
        results_dict["Mean Absolute Error (MAE)"].append(mae)
        results_dict["Root Mean Squared Error (RMSE)"].append(rmse)
        results_dict["Time taken"].append(time_taken)
        
        print(f"Model: {type(model).__name__}")
        print(f"Fold {i+1} - Mean Squared Error (MSE): {mse:.2f}")
        print(f"Fold {i+1} - Mean Absolute Error (MAE): {mae:.2f}")
        print(f"Fold {i+1} - Root Mean Squared Error (RMSE): {rmse:.2f}")
        print(f"Fold {i+1} - Time taken: {time_taken:.2f} seconds")
    
    # Calculate mean time and results for all the folds
    mean_mse = np.mean(scores_mse)
    mean_mae = np.mean(scores_mae)
    mean_rmse = np.mean(scores_rmse)
    mean_time = np.mean(times)

    # Add the mean results to the dictionary
    results_dict["Model"].append(type(model).__name__)
    results_dict["Fold"].append("Mean")
    results_dict["Mean Squared Error (MSE)"].append(mean_mse)
    results_dict["Mean Absolute Error (MAE)"].append(mean_mae)
    results_dict["Root Mean Squared Error (RMSE)"].append(mean_rmse)
    results_dict["Time taken"].append(mean_time)

    print(f"Model: {type(model).__name__}")
    print(f"Mean - Mean Squared Error (MSE): {mean_mse:.2f}")
    print(f"Mean - Mean Absolute Error (MAE): {mean_mae:.2f}")
    print(f"Mean - Root Mean Squared Error (RMSE): {mean_rmse:.2f}")
    print(f"Mean - Time taken: {mean_time:.2f} seconds")

    
#Convert the results dictionary into a pandas dataframe
results_df = pd.DataFrame.from_dict(results_dict)

#Save the results to an Excel file
results_df.to_excel("Scattered path loss - (1-40) results.xlsx", index=False)

#Print a message indicating that the results have been saved to a file
print("Results saved to results.xlsx file")
# Out:
# Model: LinearRegression
# Fold 1 - Mean Squared Error (MSE): 8.98
# Fold 1 - Mean Absolute Error (MAE): 2.39
# Fold 1 - Root Mean Squared Error (RMSE): 3.00
# Fold 1 - Time taken: 0.02 seconds
# Model: LinearRegression
# Fold 2 - Mean Squared Error (MSE): 9.36
# Fold 2 - Mean Absolute Error (MAE): 2.43
# Fold 2 - Root Mean Squared Error (RMSE): 3.06
# Fold 2 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 3 - Mean Squared Error (MSE): 8.96
# Fold 3 - Mean Absolute Error (MAE): 2.39
# Fold 3 - Root Mean Squared Error (RMSE): 2.99
# Fold 3 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 4 - Mean Squared Error (MSE): 9.32
# Fold 4 - Mean Absolute Error (MAE): 2.44
# Fold 4 - Root Mean Squared Error (RMSE): 3.05
# Fold 4 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 5 - Mean Squared Error (MSE): 9.43
# Fold 5 - Mean Absolute Error (MAE): 2.44
# Fold 5 - Root Mean Squared Error (RMSE): 3.07
# Fold 5 - Time taken: 0.01 seconds
# Model: LinearRegression
# Mean - Mean Squared Error (MSE): 9.21
# Mean - Mean Absolute Error (MAE): 2.42
# Mean - Root Mean Squared Error (RMSE): 3.04
# Mean - Time taken: 0.01 seconds
# Model: DecisionTreeRegressor
# Fold 1 - Mean Squared Error (MSE): 98.31
# Fold 1 - Mean Absolute Error (MAE): 6.28
# Fold 1 - Root Mean Squared Error (RMSE): 9.92
# Fold 1 - Time taken: 0.07 seconds
# Model: DecisionTreeRegressor
# Fold 2 - Mean Squared Error (MSE): 81.76
# Fold 2 - Mean Absolute Error (MAE): 5.66
# Fold 2 - Root Mean Squared Error (RMSE): 9.04
# Fold 2 - Time taken: 0.07 seconds
# Model: DecisionTreeRegressor
# Fold 3 - Mean Squared Error (MSE): 90.82
# Fold 3 - Mean Absolute Error (MAE): 5.95
# Fold 3 - Root Mean Squared Error (RMSE): 9.53
# Fold 3 - Time taken: 0.07 seconds
# Model: DecisionTreeRegressor
# Fold 4 - Mean Squared Error (MSE): 99.70
# Fold 4 - Mean Absolute Error (MAE): 6.47
# Fold 4 - Root Mean Squared Error (RMSE): 9.98
# Fold 4 - Time taken: 0.07 seconds
# Model: DecisionTreeRegressor
# Fold 5 - Mean Squared Error (MSE): 94.52
# Fold 5 - Mean Absolute Error (MAE): 6.16
# Fold 5 - Root Mean Squared Error (RMSE): 9.72
# Fold 5 - Time taken: 0.06 seconds
# Model: DecisionTreeRegressor
# Mean - Mean Squared Error (MSE): 93.02
# Mean - Mean Absolute Error (MAE): 6.10
# Mean - Root Mean Squared Error (RMSE): 9.64
# Mean - Time taken: 0.07 seconds
# Model: RandomForestRegressor
# Fold 1 - Mean Squared Error (MSE): 18.80
# Fold 1 - Mean Absolute Error (MAE): 3.44
# Fold 1 - Root Mean Squared Error (RMSE): 4.34
# Fold 1 - Time taken: 3.68 seconds
# Model: RandomForestRegressor
# Fold 2 - Mean Squared Error (MSE): 16.41
# Fold 2 - Mean Absolute Error (MAE): 3.28
# Fold 2 - Root Mean Squared Error (RMSE): 4.05
# Fold 2 - Time taken: 3.79 seconds
# Model: RandomForestRegressor
# Fold 3 - Mean Squared Error (MSE): 18.00
# Fold 3 - Mean Absolute Error (MAE): 3.42
# Fold 3 - Root Mean Squared Error (RMSE): 4.24
# Fold 3 - Time taken: 3.67 seconds
# Model: RandomForestRegressor
# Fold 4 - Mean Squared Error (MSE): 19.24
# Fold 4 - Mean Absolute Error (MAE): 3.52
# Fold 4 - Root Mean Squared Error (RMSE): 4.39
# Fold 4 - Time taken: 3.69 seconds
# Model: RandomForestRegressor
# Fold 5 - Mean Squared Error (MSE): 18.28
# Fold 5 - Mean Absolute Error (MAE): 3.41
# Fold 5 - Root Mean Squared Error (RMSE): 4.28
# Fold 5 - Time taken: 3.64 seconds
# Model: RandomForestRegressor
# Mean - Mean Squared Error (MSE): 18.14
# Mean - Mean Absolute Error (MAE): 3.41
# Mean - Root Mean Squared Error (RMSE): 4.26
# Mean - Time taken: 3.69 seconds
# Model: KNeighborsRegressor
# Fold 1 - Mean Squared Error (MSE): 5.84
# Fold 1 - Mean Absolute Error (MAE): 1.58
# Fold 1 - Root Mean Squared Error (RMSE): 2.42
# Fold 1 - Time taken: 0.06 seconds
# Model: KNeighborsRegressor
# Fold 2 - Mean Squared Error (MSE): 5.87
# Fold 2 - Mean Absolute Error (MAE): 1.59
# Fold 2 - Root Mean Squared Error (RMSE): 2.42
# Fold 2 - Time taken: 0.07 seconds
# Model: KNeighborsRegressor
# Fold 3 - Mean Squared Error (MSE): 6.18
# Fold 3 - Mean Absolute Error (MAE): 1.64
# Fold 3 - Root Mean Squared Error (RMSE): 2.49
# Fold 3 - Time taken: 0.11 seconds
# Model: KNeighborsRegressor
# Fold 4 - Mean Squared Error (MSE): 6.11
# Fold 4 - Mean Absolute Error (MAE): 1.63
# Fold 4 - Root Mean Squared Error (RMSE): 2.47
# Fold 4 - Time taken: 0.06 seconds
# Model: KNeighborsRegressor
# Fold 5 - Mean Squared Error (MSE): 6.72
# Fold 5 - Mean Absolute Error (MAE): 1.69
# Fold 5 - Root Mean Squared Error (RMSE): 2.59
# Fold 5 - Time taken: 0.11 seconds
# Model: KNeighborsRegressor
# Mean - Mean Squared Error (MSE): 6.14
# Mean - Mean Absolute Error (MAE): 1.62
# Mean - Root Mean Squared Error (RMSE): 2.48
# Mean - Time taken: 0.08 seconds
# Model: XGBRegressor
# Fold 1 - Mean Squared Error (MSE): 20.45
# Fold 1 - Mean Absolute Error (MAE): 3.32
# Fold 1 - Root Mean Squared Error (RMSE): 4.52
# Fold 1 - Time taken: 6.97 seconds
# Model: XGBRegressor
# Fold 2 - Mean Squared Error (MSE): 21.52
# Fold 2 - Mean Absolute Error (MAE): 3.36
# Fold 2 - Root Mean Squared Error (RMSE): 4.64
# Fold 2 - Time taken: 6.73 seconds
# Model: XGBRegressor
# Fold 3 - Mean Squared Error (MSE): 20.31
# Fold 3 - Mean Absolute Error (MAE): 3.33
# Fold 3 - Root Mean Squared Error (RMSE): 4.51
# Fold 3 - Time taken: 6.64 seconds
# Model: XGBRegressor
# Fold 4 - Mean Squared Error (MSE): 21.78
# Fold 4 - Mean Absolute Error (MAE): 3.38
# Fold 4 - Root Mean Squared Error (RMSE): 4.67
# Fold 4 - Time taken: 6.29 seconds
# Model: XGBRegressor
# Fold 5 - Mean Squared Error (MSE): 22.19
# Fold 5 - Mean Absolute Error (MAE): 3.43
# Fold 5 - Root Mean Squared Error (RMSE): 4.71
# Fold 5 - Time taken: 3.61 seconds
# Model: XGBRegressor
# Mean - Mean Squared Error (MSE): 21.25
# Mean - Mean Absolute Error (MAE): 3.36
# Mean - Root Mean Squared Error (RMSE): 4.61
# Mean - Time taken: 6.05 seconds
# Results saved to results.xlsx file
