# 1638  116.362973   95.931444   97.339096
# 1095  143.963745   97.614062  106.692059
# 1130  144.241342  106.303060  114.188943
# 1294  118.640420  103.752604  110.638311
# 860   130.060668   72.846736  102.996619
#
# [1954 rows x 24 columns]

# %%
y_train
# Out:
#           Pos X      Pos Y  Pos Z
# 233   59.678117  54.115562 -50.68
# 433  -19.191177  62.122007 -42.68
# 1430  45.890531  69.708995  -2.80
# 307   48.255475  30.881811 -47.72
# 2197  46.396180  30.387490  27.88
# ...         ...        ...    ...
# 1638  11.378450  42.552019   5.52
# 1095 -36.900143  69.397796 -16.20
# 1130 -50.886002  67.974162 -14.80
# 1294 -28.195387  33.407817  -8.24
# 860   59.591095  54.630197 -25.60
#
# [1954 rows x 3 columns]

# %% [markdown]
# # Machine Learning

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.ensemble import GradientBoostingRegressor

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, median_absolute_error
from sklearn.metrics import explained_variance_score, max_error, mean_squared_log_error

# %%
# Initialize the models
models = [LinearRegression(), DecisionTreeRegressor(), RandomForestRegressor(), KNeighborsRegressor(),  XGBRegressor()]

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, median_absolute_error, explained_variance_score
import time

# Train and evaluate each model
for model in models:
    start_time = time.time()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    end_time = time.time()
    
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    
    print(type(model).__name__)
    print("Accuracy:", model.score(X_test, y_test))
    print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
    print("Root Mean Squared Error:", rmse)
    print("R2 Score:", r2_score(y_test, y_pred))
    print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
    print("Median Absolute Error:", median_absolute_error(y_test, y_pred))
    print("Explained Variance Score:", explained_variance_score(y_test, y_pred))
    print("Time taken:", end_time - start_time)
    print("="*100)
# Out:
# LinearRegression
# Accuracy: 0.9700419308351981
# Mean Squared Error: 14.260504235852183
# Root Mean Squared Error: 3.772266781943458
# R2 Score: 0.9700419308351981
# Mean Absolute Error: 3.0352259804589408
# Median Absolute Error: 2.639919509904781
# Explained Variance Score: 0.9700814493162867
# Time taken: 0.004500389099121094
# ====================================================================================================
# DecisionTreeRegressor
# Accuracy: 0.7886252810185509
# Mean Squared Error: 104.3159356498504
# Root Mean Squared Error: 10.17179695586499
# R2 Score: 0.7886252810185509
# Mean Absolute Error: 6.569782177514906
# Median Absolute Error: 3.4470657417418678
# Explained Variance Score: 0.7891372163848028
# Time taken: 0.024500131607055664
# ====================================================================================================
# RandomForestRegressor
# Accuracy: 0.9536084781544721
# Mean Squared Error: 22.298661546862288
# Root Mean Squared Error: 4.716460224160387
# R2 Score: 0.9536084781544721
# Mean Absolute Error: 3.6857692409282112
# Median Absolute Error: 2.9509255507646266
# Explained Variance Score: 0.953753457885309
# Time taken: 1.3364980220794678
# ====================================================================================================
# KNeighborsRegressor
# Accuracy: 0.9813057097227279
# Mean Squared Error: 9.174896811552712
# Root Mean Squared Error: 2.873068251855799
# R2 Score: 0.9813057097227279
# Mean Absolute Error: 2.0198692183317504
# Median Absolute Error: 1.449593355926562
# Explained Variance Score: 0.9813125960977772
# Time taken: 0.057000160217285156
# ====================================================================================================
# XGBRegressor
# Accuracy: 0.9540698495253427
# Mean Squared Error: 24.542949567809455
# Root Mean Squared Error: 4.925670794545284
# R2 Score: 0.9540698495253427
# Mean Absolute Error: 3.662128653146867
# Median Absolute Error: 2.6509382604141485
# Explained Variance Score: 0.9542558479930093
# Time taken: 0.4184997081756592
# ====================================================================================================

# %% [markdown]
# # Cross Validation

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score, mean_absolute_error
import time


X = sensors_data
y = position_data

#Define models
models = [LinearRegression(), DecisionTreeRegressor(), RandomForestRegressor(), KNeighborsRegressor(), XGBRegressor()]

#Define k-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

#Train and evaluate each model using k-fold cross-validation
for model in models:
    # Evaluate the performance of the model using k-fold cross-validation
    scores_mse = []
    scores_mae = []
    scores_rmse = []
    times = []
    for i, (train_index, test_index) in enumerate(kfold.split(X)):
        start_time = time.time()
        
        X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[test_index]
        y_train_fold, y_val_fold = y.iloc[train_index], y.iloc[test_index]
        model.fit(X_train_fold, y_train_fold)
        y_pred_fold = model.predict(X_val_fold)
        
        
        mse = mean_squared_error(y_val_fold, y_pred_fold)
        mae = mean_absolute_error(y_val_fold, y_pred_fold)
        rmse = np.sqrt(mse)
        end_time = time.time()
        time_taken = end_time - start_time
        scores_mse.append(mse)
        scores_mae.append(mae)
        scores_rmse.append(rmse)
        times.append(time_taken)
        print(f"Model: {type(model).__name__}")
        print(f"Fold {i+1} - Mean Squared Error (MSE): {mse:.2f}")
        print(f"Fold {i+1} - Mean Absolute Error (MAE): {mae:.2f}")
        print(f"Fold {i+1} - Root Mean Squared Error (RMSE): {rmse:.2f}")
        print(f"Fold {i+1} - Time taken: {time_taken:.2f} seconds")
    
    # Calculate mean time and results for all the folds
    mean_mse = np.mean(scores_mse)
    mean_mae = np.mean(scores_mae)
    mean_rmse = np.mean(scores_rmse)
    mean_time = np.mean(times)

    # Print the mean results of the folds
    print(f"Mean MSE: {mean_mse:.2f}")
    print(f"Mean MAE: {mean_mae:.2f}")
    print(f"Mean RMSE: {mean_rmse:.2f}")
    print(f"Mean time: {mean_time:.2f} seconds")
    print("-" * 50)
# Out:
# Model: LinearRegression
# Fold 1 - Mean Squared Error (MSE): 14.26
# Fold 1 - Mean Absolute Error (MAE): 3.04
# Fold 1 - Root Mean Squared Error (RMSE): 3.78
# Fold 1 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 2 - Mean Squared Error (MSE): 15.05
# Fold 2 - Mean Absolute Error (MAE): 3.07
# Fold 2 - Root Mean Squared Error (RMSE): 3.88
# Fold 2 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 3 - Mean Squared Error (MSE): 14.46
# Fold 3 - Mean Absolute Error (MAE): 3.05
# Fold 3 - Root Mean Squared Error (RMSE): 3.80
# Fold 3 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 4 - Mean Squared Error (MSE): 14.48
# Fold 4 - Mean Absolute Error (MAE): 3.03
# Fold 4 - Root Mean Squared Error (RMSE): 3.80
# Fold 4 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 5 - Mean Squared Error (MSE): 13.93
# Fold 5 - Mean Absolute Error (MAE): 2.98
# Fold 5 - Root Mean Squared Error (RMSE): 3.73
# Fold 5 - Time taken: 0.01 seconds
# Mean MSE: 14.44
# Mean MAE: 3.03
# Mean RMSE: 3.80
# Mean time: 0.01 seconds
# --------------------------------------------------
# Model: DecisionTreeRegressor
# Fold 1 - Mean Squared Error (MSE): 100.94
# Fold 1 - Mean Absolute Error (MAE): 6.43
# Fold 1 - Root Mean Squared Error (RMSE): 10.05
# Fold 1 - Time taken: 0.03 seconds
# Model: DecisionTreeRegressor
# Fold 2 - Mean Squared Error (MSE): 88.09
# Fold 2 - Mean Absolute Error (MAE): 5.95
# Fold 2 - Root Mean Squared Error (RMSE): 9.39
# Fold 2 - Time taken: 0.03 seconds
# Model: DecisionTreeRegressor
# Fold 3 - Mean Squared Error (MSE): 98.62
# Fold 3 - Mean Absolute Error (MAE): 6.44
# Fold 3 - Root Mean Squared Error (RMSE): 9.93
# Fold 3 - Time taken: 0.03 seconds
# Model: DecisionTreeRegressor
# Fold 4 - Mean Squared Error (MSE): 90.92
# Fold 4 - Mean Absolute Error (MAE): 6.19
# Fold 4 - Root Mean Squared Error (RMSE): 9.54
# Fold 4 - Time taken: 0.03 seconds
# Model: DecisionTreeRegressor
# Fold 5 - Mean Squared Error (MSE): 84.73
# Fold 5 - Mean Absolute Error (MAE): 5.81
# Fold 5 - Root Mean Squared Error (RMSE): 9.20
# Fold 5 - Time taken: 0.03 seconds
# Mean MSE: 92.66
# Mean MAE: 6.16
# Mean RMSE: 9.62
# Mean time: 0.03 seconds
# --------------------------------------------------
# Model: RandomForestRegressor
# Fold 1 - Mean Squared Error (MSE): 22.64
# Fold 1 - Mean Absolute Error (MAE): 3.75
# Fold 1 - Root Mean Squared Error (RMSE): 4.76
# Fold 1 - Time taken: 1.37 seconds
# Model: RandomForestRegressor
# Fold 2 - Mean Squared Error (MSE): 20.90
# Fold 2 - Mean Absolute Error (MAE): 3.58
# Fold 2 - Root Mean Squared Error (RMSE): 4.57
# Fold 2 - Time taken: 1.37 seconds
# Model: RandomForestRegressor
# Fold 3 - Mean Squared Error (MSE): 22.71
# Fold 3 - Mean Absolute Error (MAE): 3.78
# Fold 3 - Root Mean Squared Error (RMSE): 4.77
# Fold 3 - Time taken: 2.14 seconds
# Model: RandomForestRegressor
# Fold 4 - Mean Squared Error (MSE): 21.70
# Fold 4 - Mean Absolute Error (MAE): 3.63
# Fold 4 - Root Mean Squared Error (RMSE): 4.66
# Fold 4 - Time taken: 2.27 seconds
# Model: RandomForestRegressor
# Fold 5 - Mean Squared Error (MSE): 21.03
# Fold 5 - Mean Absolute Error (MAE): 3.62
# Fold 5 - Root Mean Squared Error (RMSE): 4.59
# Fold 5 - Time taken: 2.27 seconds
# Mean MSE: 21.80
# Mean MAE: 3.67
# Mean RMSE: 4.67
# Mean time: 1.88 seconds
# --------------------------------------------------
# Model: KNeighborsRegressor
# Fold 1 - Mean Squared Error (MSE): 9.17
# Fold 1 - Mean Absolute Error (MAE): 2.02
# Fold 1 - Root Mean Squared Error (RMSE): 3.03
# Fold 1 - Time taken: 0.04 seconds
# Model: KNeighborsRegressor
# Fold 2 - Mean Squared Error (MSE): 9.27
# Fold 2 - Mean Absolute Error (MAE): 2.04
# Fold 2 - Root Mean Squared Error (RMSE): 3.04
# Fold 2 - Time taken: 0.05 seconds
# Model: KNeighborsRegressor
# Fold 3 - Mean Squared Error (MSE): 10.09
# Fold 3 - Mean Absolute Error (MAE): 2.09
# Fold 3 - Root Mean Squared Error (RMSE): 3.18
# Fold 3 - Time taken: 0.05 seconds
# Model: KNeighborsRegressor
# Fold 4 - Mean Squared Error (MSE): 11.54
# Fold 4 - Mean Absolute Error (MAE): 2.28
# Fold 4 - Root Mean Squared Error (RMSE): 3.40
# Fold 4 - Time taken: 0.04 seconds
# Model: KNeighborsRegressor
# Fold 5 - Mean Squared Error (MSE): 9.78
# Fold 5 - Mean Absolute Error (MAE): 2.04
# Fold 5 - Root Mean Squared Error (RMSE): 3.13
# Fold 5 - Time taken: 0.06 seconds
# Mean MSE: 9.97
# Mean MAE: 2.10
# Mean RMSE: 3.15
# Mean time: 0.05 seconds
# --------------------------------------------------
# Model: XGBRegressor
# Fold 1 - Mean Squared Error (MSE): 24.54
# Fold 1 - Mean Absolute Error (MAE): 3.66
# Fold 1 - Root Mean Squared Error (RMSE): 4.95
# Fold 1 - Time taken: 6.01 seconds
# Model: XGBRegressor
# Fold 2 - Mean Squared Error (MSE): 27.04
# Fold 2 - Mean Absolute Error (MAE): 3.78
# Fold 2 - Root Mean Squared Error (RMSE): 5.20
# Fold 2 - Time taken: 6.61 seconds
# Model: XGBRegressor
# Fold 3 - Mean Squared Error (MSE): 25.24
# Fold 3 - Mean Absolute Error (MAE): 3.66
# Fold 3 - Root Mean Squared Error (RMSE): 5.02
# Fold 3 - Time taken: 6.39 seconds
# Model: XGBRegressor
# Fold 4 - Mean Squared Error (MSE): 25.56
# Fold 4 - Mean Absolute Error (MAE): 3.70
# Fold 4 - Root Mean Squared Error (RMSE): 5.06
# Fold 4 - Time taken: 6.42 seconds
# Model: XGBRegressor
# Fold 5 - Mean Squared Error (MSE): 26.57
# Fold 5 - Mean Absolute Error (MAE): 3.71
# Fold 5 - Root Mean Squared Error (RMSE): 5.15
# Fold 5 - Time taken: 6.44 seconds
# Mean MSE: 25.79
# Mean MAE: 3.70
# Mean RMSE: 5.08
# Mean time: 6.37 seconds
# --------------------------------------------------

# %% [markdown]
# # Excel File Conversion

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score, mean_absolute_error
import time


X = sensors_data
y = position_data

# convert numpy array into pandas dataframe
X = pd.DataFrame(X)
y = pd.DataFrame(y)

# Define models
models = [LinearRegression(), DecisionTreeRegressor(), RandomForestRegressor(), KNeighborsRegressor(), XGBRegressor()]

# Define k-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# Create empty dictionary to store the results
results_dict = {
    "Model": [],
    "Fold": [],
    "Mean Squared Error (MSE)": [],
    "Mean Absolute Error (MAE)": [],
    "Root Mean Squared Error (RMSE)": [],
    "Time taken": []
}

# Train and evaluate each model using k-fold cross-validation
for model in models:
    # Evaluate the performance of the model using k-fold cross-validation
    scores_mse = []
    scores_mae = []
    scores_rmse = []
    times = []
    for i, (train_index, test_index) in enumerate(kfold.split(X)):
        start_time = time.time()
        
        X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[test_index]
        y_train_fold, y_val_fold = y.iloc[train_index], y.iloc[test_index]
        model.fit(X_train_fold, y_train_fold)
        y_pred_fold = model.predict(X_val_fold)
        
        
        mse = mean_squared_error(y_val_fold, y_pred_fold)
        mae = mean_absolute_error(y_val_fold, y_pred_fold)
        rmse = np.sqrt(mse)
        end_time = time.time()
        time_taken = end_time - start_time
        scores_mse.append(mse)
        scores_mae.append(mae)
        scores_rmse.append(rmse)
        times.append(time_taken)
        
        # Add the results to the dictionary
        results_dict["Model"].append(type(model).__name__)
        results_dict["Fold"].append(i+1)
        results_dict["Mean Squared Error (MSE)"].append(mse)
        results_dict["Mean Absolute Error (MAE)"].append(mae)
        results_dict["Root Mean Squared Error (RMSE)"].append(rmse)
        results_dict["Time taken"].append(time_taken)
        
        print(f"Model: {type(model).__name__}")
        print(f"Fold {i+1} - Mean Squared Error (MSE): {mse:.2f}")
        print(f"Fold {i+1} - Mean Absolute Error (MAE): {mae:.2f}")
        print(f"Fold {i+1} - Root Mean Squared Error (RMSE): {rmse:.2f}")
        print(f"Fold {i+1} - Time taken: {time_taken:.2f} seconds")
    
    # Calculate mean time and results for all the folds
    mean_mse = np.mean(scores_mse)
    mean_mae = np.mean(scores_mae)
    mean_rmse = np.mean(scores_rmse)
    mean_time = np.mean(times)

    # Add the mean results to the dictionary
    results_dict["Model"].append(type(model).__name__)
    results_dict["Fold"].append("Mean")
    results_dict["Mean Squared Error (MSE)"].append(mean_mse)
    results_dict["Mean Absolute Error (MAE)"].append(mean_mae)
    results_dict["Root Mean Squared Error (RMSE)"].append(mean_rmse)
    results_dict["Time taken"].append(mean_time)

    print(f"Model: {type(model).__name__}")
    print(f"Mean - Mean Squared Error (MSE): {mean_mse:.2f}")
    print(f"Mean - Mean Absolute Error (MAE): {mean_mae:.2f}")
    print(f"Mean - Root Mean Squared Error (RMSE): {mean_rmse:.2f}")
    print(f"Mean - Time taken: {mean_time:.2f} seconds")

    
#Convert the results dictionary into a pandas dataframe
results_df = pd.DataFrame.from_dict(results_dict)

#Save the results to an Excel file
results_df.to_excel("Scattered path loss - (1-24) results.xlsx", index=False)

#Print a message indicating that the results have been saved to a file
print("Results saved to results.xlsx file")
# Out:
# Model: LinearRegression
# Fold 1 - Mean Squared Error (MSE): 14.26
# Fold 1 - Mean Absolute Error (MAE): 3.04
# Fold 1 - Root Mean Squared Error (RMSE): 3.78
# Fold 1 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 2 - Mean Squared Error (MSE): 15.05
# Fold 2 - Mean Absolute Error (MAE): 3.07
# Fold 2 - Root Mean Squared Error (RMSE): 3.88
# Fold 2 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 3 - Mean Squared Error (MSE): 14.46
# Fold 3 - Mean Absolute Error (MAE): 3.05
# Fold 3 - Root Mean Squared Error (RMSE): 3.80
# Fold 3 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 4 - Mean Squared Error (MSE): 14.48
# Fold 4 - Mean Absolute Error (MAE): 3.03
# Fold 4 - Root Mean Squared Error (RMSE): 3.80
# Fold 4 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 5 - Mean Squared Error (MSE): 13.93
# Fold 5 - Mean Absolute Error (MAE): 2.98
# Fold 5 - Root Mean Squared Error (RMSE): 3.73
# Fold 5 - Time taken: 0.01 seconds
# Model: LinearRegression
# Mean - Mean Squared Error (MSE): 14.44
# Mean - Mean Absolute Error (MAE): 3.03
# Mean - Root Mean Squared Error (RMSE): 3.80
# Mean - Time taken: 0.01 seconds
# Model: DecisionTreeRegressor
# Fold 1 - Mean Squared Error (MSE): 94.93
# Fold 1 - Mean Absolute Error (MAE): 6.16
# Fold 1 - Root Mean Squared Error (RMSE): 9.74
# Fold 1 - Time taken: 0.04 seconds
# Model: DecisionTreeRegressor
# Fold 2 - Mean Squared Error (MSE): 87.62
# Fold 2 - Mean Absolute Error (MAE): 5.90
# Fold 2 - Root Mean Squared Error (RMSE): 9.36
# Fold 2 - Time taken: 0.04 seconds
# Model: DecisionTreeRegressor
# Fold 3 - Mean Squared Error (MSE): 99.83
# Fold 3 - Mean Absolute Error (MAE): 6.44
# Fold 3 - Root Mean Squared Error (RMSE): 9.99
# Fold 3 - Time taken: 0.04 seconds
# Model: DecisionTreeRegressor
# Fold 4 - Mean Squared Error (MSE): 91.61
# Fold 4 - Mean Absolute Error (MAE): 6.17
# Fold 4 - Root Mean Squared Error (RMSE): 9.57
# Fold 4 - Time taken: 0.04 seconds
# Model: DecisionTreeRegressor
# Fold 5 - Mean Squared Error (MSE): 93.16
# Fold 5 - Mean Absolute Error (MAE): 6.18
# Fold 5 - Root Mean Squared Error (RMSE): 9.65
# Fold 5 - Time taken: 0.04 seconds
# Model: DecisionTreeRegressor
# Mean - Mean Squared Error (MSE): 93.43
# Mean - Mean Absolute Error (MAE): 6.17
# Mean - Root Mean Squared Error (RMSE): 9.66
# Mean - Time taken: 0.04 seconds
# Model: RandomForestRegressor
# Fold 1 - Mean Squared Error (MSE): 21.97
# Fold 1 - Mean Absolute Error (MAE): 3.70
# Fold 1 - Root Mean Squared Error (RMSE): 4.69
# Fold 1 - Time taken: 2.33 seconds
# Model: RandomForestRegressor
# Fold 2 - Mean Squared Error (MSE): 21.07
# Fold 2 - Mean Absolute Error (MAE): 3.61
# Fold 2 - Root Mean Squared Error (RMSE): 4.59
# Fold 2 - Time taken: 2.39 seconds
# Model: RandomForestRegressor
# Fold 3 - Mean Squared Error (MSE): 21.96
# Fold 3 - Mean Absolute Error (MAE): 3.72
# Fold 3 - Root Mean Squared Error (RMSE): 4.69
# Fold 3 - Time taken: 2.35 seconds
# Model: RandomForestRegressor
# Fold 4 - Mean Squared Error (MSE): 22.41
# Fold 4 - Mean Absolute Error (MAE): 3.70
# Fold 4 - Root Mean Squared Error (RMSE): 4.73
# Fold 4 - Time taken: 2.39 seconds
# Model: RandomForestRegressor
# Fold 5 - Mean Squared Error (MSE): 20.78
# Fold 5 - Mean Absolute Error (MAE): 3.59
# Fold 5 - Root Mean Squared Error (RMSE): 4.56
# Fold 5 - Time taken: 2.45 seconds
# Model: RandomForestRegressor
# Mean - Mean Squared Error (MSE): 21.64
# Mean - Mean Absolute Error (MAE): 3.66
# Mean - Root Mean Squared Error (RMSE): 4.65
# Mean - Time taken: 2.38 seconds
# Model: KNeighborsRegressor
# Fold 1 - Mean Squared Error (MSE): 9.17
# Fold 1 - Mean Absolute Error (MAE): 2.02
# Fold 1 - Root Mean Squared Error (RMSE): 3.03
# Fold 1 - Time taken: 0.05 seconds
# Model: KNeighborsRegressor
# Fold 2 - Mean Squared Error (MSE): 9.27
# Fold 2 - Mean Absolute Error (MAE): 2.04
# Fold 2 - Root Mean Squared Error (RMSE): 3.04
# Fold 2 - Time taken: 0.06 seconds
# Model: KNeighborsRegressor
# Fold 3 - Mean Squared Error (MSE): 10.09
# Fold 3 - Mean Absolute Error (MAE): 2.09
# Fold 3 - Root Mean Squared Error (RMSE): 3.18
# Fold 3 - Time taken: 0.06 seconds
# Model: KNeighborsRegressor
# Fold 4 - Mean Squared Error (MSE): 11.54
# Fold 4 - Mean Absolute Error (MAE): 2.28
# Fold 4 - Root Mean Squared Error (RMSE): 3.40
# Fold 4 - Time taken: 0.06 seconds
# Model: KNeighborsRegressor
# Fold 5 - Mean Squared Error (MSE): 9.78
# Fold 5 - Mean Absolute Error (MAE): 2.04
# Fold 5 - Root Mean Squared Error (RMSE): 3.13
# Fold 5 - Time taken: 0.05 seconds
# Model: KNeighborsRegressor
# Mean - Mean Squared Error (MSE): 9.97
# Mean - Mean Absolute Error (MAE): 2.10
# Mean - Root Mean Squared Error (RMSE): 3.15
# Mean - Time taken: 0.05 seconds
# Model: XGBRegressor
# Fold 1 - Mean Squared Error (MSE): 24.54
# Fold 1 - Mean Absolute Error (MAE): 3.66
# Fold 1 - Root Mean Squared Error (RMSE): 4.95
# Fold 1 - Time taken: 10.44 seconds
# Model: XGBRegressor
# Fold 2 - Mean Squared Error (MSE): 27.04
# Fold 2 - Mean Absolute Error (MAE): 3.78
# Fold 2 - Root Mean Squared Error (RMSE): 5.20
# Fold 2 - Time taken: 6.72 seconds
# Model: XGBRegressor
# Fold 3 - Mean Squared Error (MSE): 25.24
# Fold 3 - Mean Absolute Error (MAE): 3.66
# Fold 3 - Root Mean Squared Error (RMSE): 5.02
# Fold 3 - Time taken: 6.36 seconds
# Model: XGBRegressor
# Fold 4 - Mean Squared Error (MSE): 25.56
# Fold 4 - Mean Absolute Error (MAE): 3.70
# Fold 4 - Root Mean Squared Error (RMSE): 5.06
# Fold 4 - Time taken: 6.34 seconds
# Model: XGBRegressor
# Fold 5 - Mean Squared Error (MSE): 26.57
# Fold 5 - Mean Absolute Error (MAE): 3.71
# Fold 5 - Root Mean Squared Error (RMSE): 5.15
# Fold 5 - Time taken: 6.36 seconds
# Model: XGBRegressor
# Mean - Mean Squared Error (MSE): 25.79
# Mean - Mean Absolute Error (MAE): 3.70
# Mean - Root Mean Squared Error (RMSE): 5.08
# Mean - Time taken: 7.25 seconds
# Results saved to results.xlsx file
