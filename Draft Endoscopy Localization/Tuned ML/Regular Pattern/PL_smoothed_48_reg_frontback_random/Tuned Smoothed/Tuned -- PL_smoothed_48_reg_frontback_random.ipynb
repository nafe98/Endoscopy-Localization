columns]

# %% [markdown]
# ### Converting to Pandas Dataframe

# %%
sensors_data = pd.DataFrame(sensors_data)

# %% [markdown]
# ### Position Data -- Labeling Columns

# %%
position_data.columns = ['Pos X', 'Pos Y', 'Pos Z']

# %%
position_data
# Out:
#           Pos X      Pos Y  Pos Z
# 0    -45.581275  30.239368 -60.00
# 1    -45.188830  30.181623 -59.96
# 2    -44.791865  30.131806 -59.92
# 3    -44.390422  30.089935 -59.88
# 4    -43.984540  30.056029 -59.84
# ...         ...        ...    ...
# 2438 -59.939858  51.788725  37.52
# 2439 -59.963718  51.389997  37.56
# 2440 -59.981583  50.990713  37.60
# 2441 -59.993448  50.591032  37.64
# 2442 -59.999315  50.191116  37.68
#
# [2443 rows x 3 columns]

# %% [markdown]
# ### Converting to Pandas Dataframe

# %%
position_data = pd.DataFrame(position_data)

# %% [markdown]
# ### Concatenating Dataframes

# %%
raw_data = pd.concat([sensors_data, position_data], axis = 1)
raw_data
# Out:
#          sensor1     sensor2     sensor3     sensor4     sensor5     sensor6  \
# 0     103.109949  133.205651   83.042591  120.306119  123.931862  148.486919
# 1     103.109949  133.205651   83.042591  120.306119  123.931862  148.486919
# 2     103.109949  133.205651   83.042591  120.306119  123.931862  148.486919
# 3     103.109949  133.205651   83.042591  120.306119  123.931862  148.486919
# 4     103.109949  133.205651   83.042591  120.306119  123.931862  148.486919
# ...          ...         ...         ...         ...         ...         ...
# 2438  130.673666  111.836664  105.548784   75.975172  151.591931  139.547208
# 2439  130.673666  111.836664  105.548784   75.975172  151.591931  139.547208
# 2440  130.673666  111.836664  105.548784   75.975172  151.591931  139.547208
# 2441  130.673666  111.836664  105.548784   75.975172  151.591931  139.547208
# 2442  130.673666  111.836664  105.548784   75.975172  151.591931  139.547208
#
#          sensor7     sensor8     sensor9    sensor10  ...   sensor42  \
# 0     110.881819  137.286978  103.621456  116.367383  ...  86.771038
# 1     110.881819  137.286978  103.621456  116.367383  ...  86.771038
# 2     110.881819  137.286978  103.621456  116.367383  ...  86.771038
# 3     110.881819  137.286978  103.621456  116.367383  ...  86.771038
# 4     110.881819  137.286978  103.621456  116.367383  ...  86.771038
# ...          ...         ...         ...         ...  ...        ...
# 2438  132.537526  119.364368  117.581730  109.290162  ...  70.091429
# 2439  132.537526  119.364368  117.581730  109.290162  ...  70.091429
# 2440  132.537526  119.364368  117.581730  109.290162  ...  70.091429
# 2441  132.537526  119.364368  117.581730  109.290162  ...  70.091429
# 2442  132.537526  119.364368  117.581730  109.290162  ...  70.091429
#
#         sensor43    sensor44    sensor45    sensor46    sensor47    sensor48  \
# 0     126.929330  113.151074  100.412663  130.746911   81.214730  116.870960
# 1     126.929330  113.151074  100.412663  130.746911   81.214730  116.870960
# 2     126.929330  113.151074  100.412663  130.746911   81.214730  116.870960
# 3     126.929330  113.151074  100.412663  130.746911   81.214730  116.870960
# 4     126.929330  113.151074  100.412663  130.746911   81.214730  116.870960
# ...          ...         ...         ...         ...         ...         ...
# 2438  136.199254  112.890068  133.533911  116.368483  107.442876   82.420608
# 2439  136.199254  112.890068  133.533911  116.368483  107.442876   82.420608
# 2440  136.199254  112.890068  133.533911  116.368483  107.442876   82.420608
# 2441  136.199254  112.890068  133.533911  116.368483  107.442876   82.420608
# 2442  136.199254  112.890068  133.533911  116.368483  107.442876   82.420608
#
#           Pos X      Pos Y  Pos Z
# 0    -45.581275  30.239368 -60.00
# 1    -45.188830  30.181623 -59.96
# 2    -44.791865  30.131806 -59.92
# 3    -44.390422  30.089935 -59.88
# 4    -43.984540  30.056029 -59.84
# ...         ...        ...    ...
# 2438 -59.939858  51.788725  37.52
# 2439 -59.963718  51.389997  37.56
# 2440 -59.981583  50.990713  37.60
# 2441 -59.993448  50.591032  37.64
# 2442 -59.999315  50.191116  37.68
#
# [2443 rows x 51 columns]

# %% [markdown]
# # Split the data into training and testing sets

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split
# 233   59.678117  54.115562 -50.68
# 433  -19.191177  62.122007 -42.68
# 1430  45.890531  69.708995  -2.80
# 307   48.255475  30.881811 -47.72
# 2197  46.396180  30.387490  27.88
# ...         ...        ...    ...
# 1638  11.378450  42.552019   5.52
# 1095 -36.900143  69.397796 -16.20
# 1130 -50.886002  67.974162 -14.80
# 1294 -28.195387  33.407817  -8.24
# 860   59.591095  54.630197 -25.60
#
# [1954 rows x 3 columns]

# %% [markdown]
# # Final Code

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score, mean_absolute_error
import time


X = sensors_data
y = position_data

# convert numpy array into pandas dataframe
X = pd.DataFrame(X)
y = pd.DataFrame(y)

# Define models
linear_regression_params = {
    'copy_X': True,
    'fit_intercept': True,
    'n_jobs': None,
    'normalize': False,
    'positive': False
}

decision_tree_regressor_params = {
    'ccp_alpha': 0.0,
    'max_features': 'auto',
    'max_leaf_nodes': None,
    'min_impurity_decrease': 0.0,
    'min_samples_leaf': 2,
    'min_samples_split': 5,
    'min_weight_fraction_leaf': 0.0
}

random_forest_regressor_params = {
    'max_features': 'sqrt',
    'max_depth': 150,
    'n_estimators': 500,
    'min_weight_fraction_leaf': 0.0,
    'min_samples_split': 2,
    'min_samples_leaf': 1,
    'max_leaf_nodes': None,
    'min_impurity_decrease': 0.0,
    'min_weight_fraction_leaf': 0.0
}

k_neighbors_regressor_params = {
    'algorithm': 'ball_tree',
    'leaf_size': 10,
    'metric': 'minkowski',
    'metric_params': None,
    'n_jobs': None,
    'n_neighbors': 11,
    'p': 2,
    'weights': 'distance'
}

xgb_regressor_params = {
    'base_score': None,
    'booster': 'dart',
    'colsample_bylevel': 0.5,
    'colsample_bynode': 0.5,
    'colsample_bytree': 0.5,
    'tree_method': 'approx',
    'eval_metric': None,
    'early_stopping_rounds': None,
    'gamma': 0.2,
    'learning_rate': 0.1,
    'max_bin': None,
    'max_delta_step': None,
    'max_depth': 3,
    'min_child_weight': 9,
    'subsample': 0.75,
    'n_estimators': 300
}


models = [LinearRegression(**linear_regression_params), 
          DecisionTreeRegressor(**decision_tree_regressor_params),
          RandomForestRegressor(**random_forest_regressor_params), 
          KNeighborsRegressor(**k_neighbors_regressor_params), 
          XGBRegressor(**xgb_regressor_params)]

# Define k-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# Create empty dictionary to store the results
results_dict = {
    "Model": [],
    "Fold": [],
    "Mean Squared Error (MSE)": [],
    "Mean Absolute Error (MAE)": [],
    "Root Mean Squared Error (RMSE)": [],
    "Time taken": []
}

# Train and evaluate each model using k-fold cross-validation
for model in models:
    # Evaluate the performance of the model using k-fold cross-validation
    scores_mse = []
    scores_mae = []
    scores_rmse = []
    times = []
    for i, (train_index, test_index) in enumerate(kfold.split(X)):
        start_time = time.time()
        
        X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[test_index]
        y_train_fold, y_val_fold = y.iloc[train_index], y.iloc[test_index]
        model.fit(X_train_fold, y_train_fold)
        y_pred_fold = model.predict(X_val_fold)
        
        
        mse = mean_squared_error(y_val_fold, y_pred_fold)
        mae = mean_absolute_error(y_val_fold, y_pred_fold)
        rmse = np.sqrt(mse)
        end_time = time.time()
        time_taken = end_time - start_time
        scores_mse.append(mse)
        scores_mae.append(mae)
        scores_rmse.append(rmse)
        times.append(time_taken)
        
        # Add the results to the dictionary
        results_dict["Model"].append(type(model).__name__)
        results_dict["Fold"].append(i+1)
        results_dict["Mean Squared Error (MSE)"].append(mse)
        results_dict["Mean Absolute Error (MAE)"].append(mae)
        results_dict["Root Mean Squared Error (RMSE)"].append(rmse)
        results_dict["Time taken"].append(time_taken)
        
        print(f"Model: {type(model).__name__}")
        print(f"Fold {i+1} - Mean Squared Error (MSE): {mse:.2f}")
        print(f"Fold {i+1} - Mean Absolute Error (MAE): {mae:.2f}")
        print(f"Fold {i+1} - Root Mean Squared Error (RMSE): {rmse:.2f}")
        print(f"Fold {i+1} - Time taken: {time_taken:.2f} seconds")
    
    # Calculate mean time and results for all the folds
    mean_mse = np.mean(scores_mse)
    mean_mae = np.mean(scores_mae)
    mean_rmse = np.mean(scores_rmse)
    mean_time = np.mean(times)

    # Add the mean results to the dictionary
    results_dict["Model"].append(type(model).__name__)
    results_dict["Fold"].append("Mean")
    results_dict["Mean Squared Error (MSE)"].append(mean_mse)
    results_dict["Mean Absolute Error (MAE)"].append(mean_mae)
    results_dict["Root Mean Squared Error (RMSE)"].append(mean_rmse)
    results_dict["Time taken"].append(mean_time)

    print(f"Model: {type(model).__name__}")
    print(f"Mean - Mean Squared Error (MSE): {mean_mse:.2f}")
    print(f"Mean - Mean Absolute Error (MAE): {mean_mae:.2f}")
    print(f"Mean - Root Mean Squared Error (RMSE): {mean_rmse:.2f}")
    print(f"Mean - Time taken: {mean_time:.2f} seconds")

    
#Convert the results dictionary into a pandas dataframe
results_df = pd.DataFrame.from_dict(results_dict)

#Save the results to an Excel file
results_df.to_excel("TUNED -- PL_smoothed_48_reg_frontback_random Result.xlsx", index=False)

#Print a message indicating that the results have been saved to a file
print("TUNED -- PL_smoothed_48_reg_frontback_random Result.xlsx file")
# Out:
# C:\Users\nafem\anaconda3\envs\gpu\lib\site-packages\sklearn\linear_model\_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# C:\Users\nafem\anaconda3\envs\gpu\lib\site-packages\sklearn\linear_model\_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# C:\Users\nafem\anaconda3\envs\gpu\lib\site-packages\sklearn\linear_model\_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# C:\Users\nafem\anaconda3\envs\gpu\lib\site-packages\sklearn\linear_model\_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# C:\Users\nafem\anaconda3\envs\gpu\lib\site-packages\sklearn\linear_model\_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# C:\Users\nafem\anaconda3\envs\gpu\lib\site-packages\sklearn\tree\_classes.py:306: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# C:\Users\nafem\anaconda3\envs\gpu\lib\site-packages\sklearn\tree\_classes.py:306: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# C:\Users\nafem\anaconda3\envs\gpu\lib\site-packages\sklearn\tree\_classes.py:306: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# C:\Users\nafem\anaconda3\envs\gpu\lib\site-packages\sklearn\tree\_classes.py:306: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# C:\Users\nafem\anaconda3\envs\gpu\lib\site-packages\sklearn\tree\_classes.py:306: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# Model: LinearRegression
# Fold 1 - Mean Squared Error (MSE): 0.44
# Fold 1 - Mean Absolute Error (MAE): 0.53
# Fold 1 - Root Mean Squared Error (RMSE): 0.66
# Fold 1 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 2 - Mean Squared Error (MSE): 0.44
# Fold 2 - Mean Absolute Error (MAE): 0.51
# Fold 2 - Root Mean Squared Error (RMSE): 0.67
# Fold 2 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 3 - Mean Squared Error (MSE): 0.44
# Fold 3 - Mean Absolute Error (MAE): 0.51
# Fold 3 - Root Mean Squared Error (RMSE): 0.66
# Fold 3 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 4 - Mean Squared Error (MSE): 0.44
# Fold 4 - Mean Absolute Error (MAE): 0.51
# Fold 4 - Root Mean Squared Error (RMSE): 0.66
# Fold 4 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 5 - Mean Squared Error (MSE): 0.42
# Fold 5 - Mean Absolute Error (MAE): 0.50
# Fold 5 - Root Mean Squared Error (RMSE): 0.65
# Fold 5 - Time taken: 0.01 seconds
# Model: LinearRegression
# Mean - Mean Squared Error (MSE): 0.44
# Mean - Mean Absolute Error (MAE): 0.51
# Mean - Root Mean Squared Error (RMSE): 0.66
# Mean - Time taken: 0.01 seconds
# Model: DecisionTreeRegressor
# Fold 1 - Mean Squared Error (MSE): 3.80
# Fold 1 - Mean Absolute Error (MAE): 0.66
# Fold 1 - Root Mean Squared Error (RMSE): 1.95
# Fold 1 - Time taken: 0.04 seconds
# Model: DecisionTreeRegressor
# Fold 2 - Mean Squared Error (MSE): 2.33
# Fold 2 - Mean Absolute Error (MAE): 0.60
# Fold 2 - Root Mean Squared Error (RMSE): 1.53
# Fold 2 - Time taken: 0.04 seconds
# Model: DecisionTreeRegressor
# Fold 3 - Mean Squared Error (MSE): 2.11
# Fold 3 - Mean Absolute Error (MAE): 0.60
# Fold 3 - Root Mean Squared Error (RMSE): 1.45
# Fold 3 - Time taken: 0.04 seconds
# Model: DecisionTreeRegressor
# Fold 4 - Mean Squared Error (MSE): 0.89
# Fold 4 - Mean Absolute Error (MAE): 0.55
# Fold 4 - Root Mean Squared Error (RMSE): 0.94
# Fold 4 - Time taken: 0.04 seconds
# Model: DecisionTreeRegressor
# Fold 5 - Mean Squared Error (MSE): 0.95
# Fold 5 - Mean Absolute Error (MAE): 0.56
# Fold 5 - Root Mean Squared Error (RMSE): 0.97
# Fold 5 - Time taken: 0.05 seconds
# Model: DecisionTreeRegressor
# Mean - Mean Squared Error (MSE): 2.02
# Mean - Mean Absolute Error (MAE): 0.59
# Mean - Root Mean Squared Error (RMSE): 1.37
# Mean - Time taken: 0.04 seconds
# Model: RandomForestRegressor
# Fold 1 - Mean Squared Error (MSE): 0.06
# Fold 1 - Mean Absolute Error (MAE): 0.16
# Fold 1 - Root Mean Squared Error (RMSE): 0.25
# Fold 1 - Time taken: 3.10 seconds
# Model: RandomForestRegressor
# Fold 2 - Mean Squared Error (MSE): 0.06
# Fold 2 - Mean Absolute Error (MAE): 0.16
# Fold 2 - Root Mean Squared Error (RMSE): 0.25
# Fold 2 - Time taken: 3.37 seconds
# Model: RandomForestRegressor
# Fold 3 - Mean Squared Error (MSE): 0.07
# Fold 3 - Mean Absolute Error (MAE): 0.17
# Fold 3 - Root Mean Squared Error (RMSE): 0.27
# Fold 3 - Time taken: 3.32 seconds
# Model: RandomForestRegressor
# Fold 4 - Mean Squared Error (MSE): 0.04
# Fold 4 - Mean Absolute Error (MAE): 0.15
# Fold 4 - Root Mean Squared Error (RMSE): 0.21
# Fold 4 - Time taken: 3.29 seconds
# Model: RandomForestRegressor
# Fold 5 - Mean Squared Error (MSE): 0.06
# Fold 5 - Mean Absolute Error (MAE): 0.16
# Fold 5 - Root Mean Squared Error (RMSE): 0.25
# Fold 5 - Time taken: 3.25 seconds
# Model: RandomForestRegressor
# Mean - Mean Squared Error (MSE): 0.06
# Mean - Mean Absolute Error (MAE): 0.16
# Mean - Root Mean Squared Error (RMSE): 0.24
# Mean - Time taken: 3.26 seconds
# Model: KNeighborsRegressor
# Fold 1 - Mean Squared Error (MSE): 0.05
# Fold 1 - Mean Absolute Error (MAE): 0.14
# Fold 1 - Root Mean Squared Error (RMSE): 0.22
# Fold 1 - Time taken: 0.01 seconds
# Model: KNeighborsRegressor
# Fold 2 - Mean Squared Error (MSE): 0.05
# Fold 2 - Mean Absolute Error (MAE): 0.13
# Fold 2 - Root Mean Squared Error (RMSE): 0.23
# Fold 2 - Time taken: 0.02 seconds
# Model: KNeighborsRegressor
# Fold 3 - Mean Squared Error (MSE): 0.06
# Fold 3 - Mean Absolute Error (MAE): 0.13
# Fold 3 - Root Mean Squared Error (RMSE): 0.25
# Fold 3 - Time taken: 0.02 seconds
# Model: KNeighborsRegressor
# Fold 4 - Mean Squared Error (MSE): 0.05
# Fold 4 - Mean Absolute Error (MAE): 0.13
# Fold 4 - Root Mean Squared Error (RMSE): 0.22
# Fold 4 - Time taken: 0.02 seconds
# Model: KNeighborsRegressor
# Fold 5 - Mean Squared Error (MSE): 0.05
# Fold 5 - Mean Absolute Error (MAE): 0.13
# Fold 5 - Root Mean Squared Error (RMSE): 0.22
# Fold 5 - Time taken: 0.02 seconds
# Model: KNeighborsRegressor
# Mean - Mean Squared Error (MSE): 0.05
# Mean - Mean Absolute Error (MAE): 0.13
# Mean - Root Mean Squared Error (RMSE): 0.23
# Mean - Time taken: 0.01 seconds
# Model: XGBRegressor
# Fold 1 - Mean Squared Error (MSE): 0.71
# Fold 1 - Mean Absolute Error (MAE): 0.59
# Fold 1 - Root Mean Squared Error (RMSE): 0.84
# Fold 1 - Time taken: 28.42 seconds
# Model: XGBRegressor
# Fold 2 - Mean Squared Error (MSE): 0.72
# Fold 2 - Mean Absolute Error (MAE): 0.60
# Fold 2 - Root Mean Squared Error (RMSE): 0.85
# Fold 2 - Time taken: 28.54 seconds
# Model: XGBRegressor
# Fold 3 - Mean Squared Error (MSE): 0.69
# Fold 3 - Mean Absolute Error (MAE): 0.59
# Fold 3 - Root Mean Squared Error (RMSE): 0.83
# Fold 3 - Time taken: 29.05 seconds
# Model: XGBRegressor
# Fold 4 - Mean Squared Error (MSE): 0.76
# Fold 4 - Mean Absolute Error (MAE): 0.61
# Fold 4 - Root Mean Squared Error (RMSE): 0.87
# Fold 4 - Time taken: 29.06 seconds
# Model: XGBRegressor
# Fold 5 - Mean Squared Error (MSE): 0.69
# Fold 5 - Mean Absolute Error (MAE): 0.59
# Fold 5 - Root Mean Squared Error (RMSE): 0.83
# Fold 5 - Time taken: 29.21 seconds
# Model: XGBRegressor
# Mean - Mean Squared Error (MSE): 0.71
# Mean - Mean Absolute Error (MAE): 0.60
# Mean - Root Mean Squared Error (RMSE): 0.84
# Mean - Time taken: 28.86 seconds
# TUNED -- PL_smoothed_48_reg_frontback_random Result.xlsx file
