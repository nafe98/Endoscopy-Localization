#
#         sensor40    sensor41    sensor42    sensor43    sensor44    sensor45  \
# 233    70.868650  114.812610  133.837908   78.608175  114.219667  117.875066
# 433   100.782611  113.015658  133.140756   73.878253   98.580630   85.490297
# 1430   71.178049  128.646922  130.300147   89.263434   97.030917  119.379386
# 307    81.924378  108.138628  137.101919   84.604905  111.323180  105.346615
# 2197   78.829267  118.248526   97.558165  101.135168   90.792386  119.113009
# ...          ...         ...         ...         ...         ...         ...
# 1638   86.829365  114.240576  108.627557   82.664938   85.666923  113.566035
# 1095   94.847368  122.072991  128.274766   81.506960   99.398170   96.127788
# 1130  107.995169  123.913010  137.842335   91.754458   96.438745   84.224234
# 1294   98.766962  100.946498  108.898744   93.620816   95.863468   85.643723
# 860    70.169676  116.633641  126.898118   90.727131   99.330339  119.779694
#
#         sensor46    sensor47    sensor48
# 233   142.040541   86.443714  120.082950
# 433   108.315661  100.758213  119.530107
# 1430  126.398258   96.351992   98.218348
# 307   133.605394   77.867766  112.569545
# 2197  107.598524  106.189985   80.538066
# ...          ...         ...         ...
# 1638  116.390917  106.729169   99.875169
# 1095  107.069547  106.618846  126.393930
# 1130   96.045595  118.462472  130.493556
# 1294   99.962844  115.026165  106.669340
# 860   124.670193   82.136044   99.007660
#
# [1954 rows x 48 columns]

# %%
y_train
# Out:
#           Pos X      Pos Y  Pos Z
# 233   59.678117  54.115562 -50.68
# 433  -19.191177  62.122007 -42.68
# 1430  45.890531  69.708995  -2.80
# 307   48.255475  30.881811 -47.72
# 2197  46.396180  30.387490  27.88
# ...         ...        ...    ...
# 1638  11.378450  42.552019   5.52
# 1095 -36.900143  69.397796 -16.20
# 1130 -50.886002  67.974162 -14.80
# 1294 -28.195387  33.407817  -8.24
# 860   59.591095  54.630197 -25.60
#
# [1954 rows x 3 columns]

# %%
results_dict = {
    "Model": [],
    "Fold": [],
    "Mean Squared Error (MSE)": [],
    "Mean Absolute Error (MAE)": [],
    "Root Mean Squared Error (RMSE)": [],
    "Time taken": [],
    "Best Parameters": []
}

# %%
from sklearn.linear_model import LinearRegression

# Create a Decision Tree Regressor object
dt_reg = LinearRegression()

# Print all the parameters of the Decision Tree Regressor
print(dt_reg.get_params())
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': 'deprecated', 'positive': False}

# %%
param_grid = {
    'fit_intercept': [True, False],
    'normalize': [True, False],
    'copy_X': [True, False],
}

# %%
results_dict = {
    "Model": [],
    "Fold": [],
    "Mean Squared Error (MSE)": [],
    "Mean Absolute Error (MAE)": [],
    "Root Mean Squared Error (RMSE)": [],
    "Time taken": [],
    "Best Parameters": []
}

# %%
# Define hyperparameters to search for each model
models_params = [    (LinearRegression(),{
    'fit_intercept': [True, False],
    'normalize': [True, False],
    'copy_X': [True, False],
})]

# Create empty dictionary to store the results
results_dict = {
    "Model": [],
    "Fold": [],
    "Mean Squared Error (MSE)": [],
    "Mean Absolute Error (MAE)": [],
    "Root Mean Squared Error (RMSE)": [],
    "Time taken": [],
    "Best Parameters": []
}

# Loop over models and perform hyperparameter tuning
for model, params in models_params:
    start_time = time.time()
    grid_search = GridSearchCV(model, params, cv=kfold, scoring='neg_mean_squared_error', n_jobs=-1)
    grid_search.fit(X, y)
    end_time = time.time()
    results_dict["Model"].append(str(model).split('(')[0])
    results_dict["Fold"].append("Grid Search")
    results_dict["Mean Squared Error (MSE)"].append(-grid_search.best_score_)
    results_dict["Mean Absolute Error (MAE)"].append(mean_absolute_error(y, grid_search.predict(X)))
    results_dict["Root Mean Squared Error (RMSE)"].append(np.sqrt(-grid_search.best_score_))
    results_dict["Time taken"].append(end_time - start_time)
    results_dict["Best Parameters"].append(grid_search.best_params_)

    start_time = time.time()
    random_search = RandomizedSearchCV(model, params, cv=kfold, scoring='neg_mean_squared_error', n_jobs=-1)
    random_search.fit(X, y)
    end_time = time.time()
results_dict["Model"].append(str(model)
# Out:
#   Cell In[46], line 37
#     results_dict["Model"].append(str(model)
#                                            ^
# SyntaxError: unexpected EOF while parsing

# %%
X = sensors_data
y = position_data

# %%
# Define hyperparameters to search for each model
models_params = [(LinearRegression(), {
    'fit_intercept': [True, False],
    'normalize': [True, False],
    'copy_X': [True, False],
})]

# Create empty dictionary to store the results
results_dict = {
    "Model": [],
    "Fold": [],
    "Mean Squared Error (MSE)": [],
    "Mean Absolute Error (MAE)": [],
    "Root Mean Squared Error (RMSE)": [],
    "Time taken": [],
    "Best Parameters": []
}

# Loop over models and perform hyperparameter tuning
for model, params in models_params:
    start_time = time.time()
    grid_search = GridSearchCV(model, params, cv=kfold, scoring='neg_mean_squared_error', n_jobs=-1)
    grid_search.fit(X, y)
    end_time = time.time()
    results_dict["Model"].append(str(model).split('(')[0])
    results_dict["Fold"].append("Grid Search")
    results_dict["Mean Squared Error (MSE)"].append(-grid_search.best_score_)
    results_dict["Mean Absolute Error (MAE)"].append(mean_absolute_error(y, grid_search.predict(X)))
    results_dict["Root Mean Squared Error (RMSE)"].append(np.sqrt(-grid_search.best_score_))
    results_dict["Time taken"].append(end_time - start_time)
    results_dict["Best Parameters"].append(grid_search.best_params_)

    start_time = time.time()
    random_search = RandomizedSearchCV(model, params, cv=kfold, scoring='neg_mean_squared_error', n_jobs=-1)
    random_search.fit(X, y)
    end_time = time.time()
    results_dict["Model"].append(str(model).split('(')[0])
    results_dict["Fold"].append("Random Search")
    results_dict["Mean Squared Error (MSE)"].append(-random_search.best_score_)
    results_dict["Mean Absolute Error (MAE)"].append(mean_absolute_error(y, random_search.predict(X)))
    results_dict["Root Mean Squared Error (RMSE)"].append(np.sqrt(-random_search.best_score_))
    results_dict["Time taken"].append(end_time - start_time)
    results_dict["Best Parameters"].append(random_search.best_params_)
# Out:
# C:\Users\nafem\anaconda3\envs\gpu\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# C:\Users\nafem\anaconda3\envs\gpu\lib\site-packages\sklearn\model_selection\_search.py:306: UserWarning: The total space of parameters 8 is smaller than n_iter=10. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\Users\nafem\anaconda3\envs\gpu\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
import time
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

from sklearn.model_selection import KFold

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, median_absolute_error
from sklearn.metrics import explained_variance_score, max_error, mean_squared_log_error

# %% [markdown]
# # Vanilla Machine Learning

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, median_absolute_error
from sklearn.metrics import explained_variance_score, max_error, mean_squared_log_error

# %%
# Initialize the models
models = [LinearRegression(), DecisionTreeRegressor(), RandomForestRegressor(), KNeighborsRegressor(),  XGBRegressor()]

# %%
# Train and evaluate each model
for model in models:
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(type(model).__name__)
    print("Accuracy:", model.score(X_test, y_test))
    print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
    print("R2 Score:", r2_score(y_test, y_pred))
    print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
    print("Median Absolute Error:", median_absolute_error(y_test, y_pred))
    print("Explained Variance Score:", explained_variance_score(y_test, y_pred))
    print("="*100)
# Out:
# LinearRegression
# Accuracy: 0.9819661612292244
# Mean Squared Error: 8.117270652181114
# R2 Score: 0.9819661612292244
# Mean Absolute Error: 2.2775661060056405
# Median Absolute Error: 1.9150870212415327
# Explained Variance Score: 0.9819768184190326
# ====================================================================================================
# DecisionTreeRegressor
# Accuracy: 0.8378197518381993
# Mean Squared Error: 83.92093311498569
# R2 Score: 0.8378197518381993
# Mean Absolute Error: 5.730014020024863
# Median Absolute Error: 2.972990414979499
# Explained Variance Score: 0.8379378985462642
# ====================================================================================================
# RandomForestRegressor
# Accuracy: 0.9590348822811091
# Mean Squared Error: 19.678141099038523
# R2 Score: 0.9590348822811091
# Mean Absolute Error: 3.4754824385459777
# Median Absolute Error: 2.969826291538707
# Explained Variance Score: 0.9591194100895675
# ====================================================================================================
# KNeighborsRegressor
# Accuracy: 0.9891197625738051
# Mean Squared Error: 5.118437746829768
# R2 Score: 0.9891197625738051
# Mean Absolute Error: 1.4900032430550105
# Median Absolute Error: 1.0143520423481451
# Explained Variance Score: 0.9891262422820692
# ====================================================================================================
# XGBRegressor
# Accuracy: 0.9584470568552281
# Mean Squared Error: 20.829691989747413
# R2 Score: 0.9584470568552281
# Mean Absolute Error: 3.3173364385934687
# Median Absolute Error: 2.371696950385356
# Explained Variance Score: 0.9584702093418532
# ====================================================================================================

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# Define hyperparameters for each model
lr_params = {'fit_intercept': [True, False], 'normalize': [True, False]}
dt_params = {'max_depth': [3, 5, 7, 10], 'min_samples_split': [2, 5, 10]}
rf_params = {'n_estimators': [50, 100, 200], 'max_depth': [3, 5, 7], 'min_samples_split': [2, 5, 10]}
knn_params = {'n_neighbors': [3, 5, 7, 10], 'weights': ['uniform', 'distance']}
xgb_params = {'learning_rate': [0.01, 0.1, 0.3], 'max_depth': [3, 5, 7], 'n_estimators': [50, 100, 200]}

# Define hyperparameters for each model
models_params = [    (LinearRegression(), lr_params),    (DecisionTreeRegressor(), dt_params),    (RandomForestRegressor(), rf_params),    (KNeighborsRegressor(), knn_params),    (XGBRegressor(), xgb_params)]

# Loop over models and perform hyperparameter tuning
for model, params in models_params:
    start_time = time.time()
    grid_search = GridSearchCV(model, params, cv=kfold, scoring='neg_mean_squared_error', n_jobs=-1)
    grid_search.fit(X, y)
    end_time = time.time()
    results_dict["Model"].append(str(model).split('(')[0])
    results_dict["Fold"].append("Grid Search")
    results_dict["Mean Squared Error (MSE)"].append(-grid_search.best_score_)
    results_dict["Mean Absolute Error (MAE)"].append(mean_absolute_error(y, grid_search.predict(X)))
    results_dict["Root Mean Squared Error (RMSE)"].append(np.sqrt(-grid_search.best_score_))
    results_dict["Time taken"].append(end_time - start_time)

    start_time = time.time()
    random_search = RandomizedSearchCV(model, params, cv=kfold, scoring='neg_mean_squared_error', n_jobs=-1)
    random_search.fit(X, y)
    end_time = time.time()
    results_dict["Model"].append(str(model).split('(')[0])
    results_dict["Fold"].append("Randomized Search")
    results_dict["Mean Squared Error (MSE)"].append(-random_search.best_score_)
    results_dict["Mean Absolute Error (MAE)"].append(mean_absolute_error(y, random_search.predict(X)))
    results_dict["Root Mean Squared Error (RMSE)"].append(np.sqrt(-random_search.best_score_))
    results_dict["Time taken"].append(end_time - start_time)
# Out:
# C:\Users\nafem\anaconda3\envs\gpu\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# C:\Users\nafem\anaconda3\envs\gpu\lib\site-packages\sklearn\model_selection\_search.py:306: UserWarning: The total space of parameters 4 is smaller than n_iter=10. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\Users\nafem\anaconda3\envs\gpu\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# C:\Users\nafem\anaconda3\envs\gpu\lib\site-packages\sklearn\model_selection\_search.py:306: UserWarning: The total space of parameters 8 is smaller than n_iter=10. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(

# %%
# Loop over models and perform hyperparameter tuning
for model, params in models_params:
    start_time = time.time()
    grid_search = GridSearchCV(model, params, cv=kfold, scoring='neg_mean_squared_error', n_jobs=-1)
    grid_search.fit(X, y)
    end_time = time.time()
    results_dict["Model"].append(str(model).split('(')[0])
    results_dict["Fold"].append("Grid Search")
    results_dict["Mean Squared Error (MSE)"].append(-grid_search.best_score_)
    results_dict["Mean Absolute Error (MAE)"].append(mean_absolute_error(y, grid_search.predict(X)))
    results_dict["Root Mean Squared Error (RMSE)"].append(np.sqrt(-grid_search.best_score_))
    results_dict["Time taken"].append(end_time - start_time)
    results_dict["Best Parameters"].append(grid_search.best_params_)

    start_time = time.time()
    random_search = RandomizedSearchCV(model, params, cv=kfold, scoring='neg_mean_squared_error', n_jobs=-1)
    random_search.fit(X, y)
    end_time = time.time()
    results_dict["Model"].append(str(model).split('(')[0])
    results_dict["Fold"].append("Randomized Search")
    results_dict["Mean Squared Error (MSE)"].append(-random_search.best_score_)
    results_dict["Mean Absolute Error (MAE)"].append(mean_absolute_error(y, random_search.predict(X)))
    results_dict["Root Mean Squared Error (RMSE)"].append(np.sqrt(-random_search.best_score_))
    results_dict["Time taken"].append(end_time - start_time)
    results_dict["Best Parameters"].append(random_search.best_params_)

# Create a pandas dataframe from the results dictionary
results_df = pd.DataFrame(results_dict)

# Group the results by model and fold, and display the best parameters for each group
grouped_results = results_df.groupby(["Model", "Fold"]).apply(lambda x: x.loc[x["Mean Squared Error (MSE)"].idxmin()]).reset_index(drop=True)
display(grouped_results[["Model", "Fold", "Best Parameters"]])
# Out:
# C:\Users\nafem\anaconda3\envs\gpu\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# C:\Users\nafem\anaconda3\envs\gpu\lib\site-packages\sklearn\model_selection\_search.py:306: UserWarning: The total space of parameters 4 is smaller than n_iter=10. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\Users\nafem\anaconda3\envs\gpu\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# C:\Users\nafem\anaconda3\envs\gpu\lib\site-packages\sklearn\model_selection\_search.py:306: UserWarning: The total space of parameters 8 is smaller than n_iter=10. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
#                    Model               Fold  \
# 0  DecisionTreeRegressor        Grid Search
# 1  DecisionTreeRegressor  Randomized Search
# 2    KNeighborsRegressor        Grid Search
# 3    KNeighborsRegressor  Randomized Search
# 4       LinearRegression        Grid Search
# 5       LinearRegression  Randomized Search
# 6  RandomForestRegressor        Grid Search
# 7  RandomForestRegressor  Randomized Search
# 8           XGBRegressor        Grid Search
# 9           XGBRegressor  Randomized Search
#
#                                      Best Parameters
# 0         {'max_depth': 10, 'min_samples_split': 10}
# 1         {'min_samples_split': 10, 'max_depth': 10}
# 2         {'n_neighbors': 10, 'weights': 'distance'}
# 3         {'weights': 'distance', 'n_neighbors': 10}
# 4         {'fit_intercept': True, 'normalize': True}
# 5         {'normalize': True, 'fit_intercept': True}
# 6  {'max_depth': 7, 'min_samples_split': 2, 'n_es...
# 7  {'n_estimators': 100, 'min_samples_split': 2, ...
# 8  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...
# 9  {'n_estimators': 100, 'max_depth': 5, 'learnin...

# %%
############## Best Code ###########

# %%
# Define hyperparameters to search for each model
models_params = [(LinearRegression(), {
    'fit_intercept': [True, False],
    'normalize': [True, False],
    'copy_X': [True, False],
})]

# Create empty dictionary to store the results
results_dict = {
    "Model": [],
    "Fold": [],
    "Mean Squared Error (MSE)": [],
    "Mean Absolute Error (MAE)": [],
    "Root Mean Squared Error (RMSE)": [],
    "Time taken": [],
    "Best Parameters": []
}

# Loop over models and perform hyperparameter tuning
for model, params in models_params:
    start_time = time.time()
    grid_search = GridSearchCV(model, params, cv=kfold, scoring='neg_mean_squared_error', n_jobs=-1)
    grid_search.fit(X, y)
    end_time = time.time()
    results_dict["Model"].append(str(model).split('(')[0])
    results_dict["Fold"].append("Grid Search")
    results_dict["Mean Squared Error (MSE)"].append(-grid_search.best_score_)
    results_dict["Mean Absolute Error (MAE)"].append(mean_absolute_error(y, grid_search.predict(X)))
    results_dict["Root Mean Squared Error (RMSE)"].append(np.sqrt(-grid_search.best_score_))
    results_dict["Time taken"].append(end_time - start_time)
    results_dict["Best Parameters"].append(grid_search.best_params_)

    start_time = time.time()
    random_search = RandomizedSearchCV(model, params, cv=kfold, scoring='neg_mean_squared_error', n_jobs=-1)
    random_search.fit(X, y)
    end_time = time.time()
    results_dict["Model"].append(str(model).split('(')[0])
    results_dict["Fold"].append("Randomized Search")
    results_dict["Mean Squared Error (MSE)"].append(-random_search.best_score_)
    results_dict["Mean Absolute Error (MAE)"].append(mean_absolute_error(y, random_search.predict(X)))
    results_dict["Root Mean Squared Error (RMSE)"].append(np.sqrt(-random_search.best_score_))
    results_dict["Time taken"].append(end_time - start_time)
    results_dict["Best Parameters"].append(random_search.best_params_)

# Create a pandas dataframe from the results dictionary
results_df = pd.DataFrame(results_dict)

# Group the results by model and fold, and display the best parameters for each group
grouped_results = results_df.groupby(["Model", "Fold"]).apply(lambda x: x.loc[x["Mean Squared Error (MSE)"].idxmin()]).reset_index(drop=True)
display(grouped_results[["Model", "Fold", "Best Parameters"]])
# Out:
# C:\Users\nafem\anaconda3\envs\gpu\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# C:\Users\nafem\anaconda3\envs\gpu\lib\site-packages\sklearn\model_selection\_search.py:306: UserWarning: The total space of parameters 8 is smaller than n_iter=10. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\Users\nafem\anaconda3\envs\gpu\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
#               Model               Fold  \
# 0  LinearRegression        Grid Search
# 1  LinearRegression  Randomized Search
#
#                                      Best Parameters
# 0  {'copy_X': True, 'fit_intercept': True, 'norma...
# 1  {'normalize': True, 'fit_intercept': True, 'co...

# %%
import pandas as pd

# Set pandas display options to show all columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Display the grouped results dataframe
display(grouped_results)
# Out:
#               Model               Fold  Mean Squared Error (MSE)  \
# 0  LinearRegression        Grid Search                  7.893937
# 1  LinearRegression  Randomized Search                  7.893937
#
#    Mean Absolute Error (MAE)  Root Mean Squared Error (RMSE)  Time taken  \
# 0                   2.197241                        2.809615    2.062808
# 1                   2.197241                        2.809615    0.156013
#
#                                      Best Parameters
# 0  {'copy_X': True, 'fit_intercept': True, 'norma...
# 1  {'normalize': True, 'fit_intercept': True, 'co...

# %%
# Create a new column with the Best Parameters in full sentence format
grouped_results["Full Parameters"] = grouped_results["Best Parameters"].apply(lambda x: ', '.join(['{}={}'.format(key, val) for key, val in x.items()]))

# Display the grouped results with the Full Parameters column
display(grouped_results[["Model", "Fold", "Full Parameters", "Mean Squared Error (MSE)", "Mean Absolute Error (MAE)", "Root Mean Squared Error (RMSE)", "Time taken"]])
# Out:
#               Model               Fold  \
# 0  LinearRegression        Grid Search
# 1  LinearRegression  Randomized Search
#
#                                    Full Parameters  Mean Squared Error (MSE)  \
# 0  copy_X=True, fit_intercept=True, normalize=True                  7.893937
# 1  normalize=True, fit_intercept=True, copy_X=True                  7.893937
#
#    Mean Absolute Error (MAE)  Root Mean Squared Error (RMSE)  Time taken
# 0                   2.197241                        2.809615    2.062808
# 1                   2.197241                        2.809615    0.156013
