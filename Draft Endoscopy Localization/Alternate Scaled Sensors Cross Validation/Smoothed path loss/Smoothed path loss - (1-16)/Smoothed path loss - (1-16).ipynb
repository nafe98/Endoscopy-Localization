# %% [markdown]
# # Importing Libraries for Data Engineering

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Loading Dataset

# %%
sensors_data = pd.read_excel('Smoothed path loss of 48 sensors for 2443 positions.xlsx', header=None)

# %%
sensors_data
# Out:
#               0           1           2           3           4           5   \
# 0     103.365475  131.254765   82.406446  118.490072  124.741424  148.572789
# 1     103.365475  131.254765   82.406446  118.490072  124.741424  148.572789
# 2     103.365475  131.254765   82.406446  118.490072  124.741424  148.572789
# 3     103.365475  131.254765   82.406446  118.490072  124.741424  148.572789
# 4     103.365475  131.254765   82.406446  118.490072  124.741424  148.572789
# ...          ...         ...         ...         ...         ...         ...
# 2438  130.845198  115.244199  106.851047   78.347576  153.056587  140.522035
# 2439  130.845198  115.244199  106.851047   78.347576  153.056587  140.522035
# 2440  130.845198  115.244199  106.851047   78.347576  153.056587  140.522035
# 2441  130.845198  115.244199  106.851047   78.347576  153.056587  140.522035
# 2442  130.845198  115.244199  106.851047   78.347576  153.056587  140.522035
#
#               6           7           8           9   ...          38  \
# 0     110.782852  137.480311  101.466941  123.421399  ...  107.203207
# 1     110.782852  137.480311  101.466941  123.421399  ...  107.203207
# 2     110.782852  137.480311  101.466941  123.421399  ...  107.203207
# 3     110.782852  137.480311  101.466941  123.421399  ...  107.203207
# 4     110.782852  137.480311  101.466941  123.421399  ...  107.203207
# ...          ...         ...         ...         ...  ...         ...
# 2438  133.823333  116.302351  121.182268  110.310482  ...  119.411902
# 2439  133.823333  116.302351  121.182268  110.310482  ...  119.411902
# 2440  133.823333  116.302351  121.182268  110.310482  ...  119.411902
# 2441  133.823333  116.302351  121.182268  110.310482  ...  119.411902
# 2442  133.823333  116.302351  121.182268  110.310482  ...  119.411902
#
#               39          40          41          42          43          44  \
# 0     119.753930   99.374723  130.509610   74.261665  114.452393  109.175534
# 1     119.753930   99.374723  130.509610   74.261665  114.452393  109.175534
# 2     119.753930   99.374723  130.509610   74.261665  114.452393  109.175534
# 3     119.753930   99.374723  130.509610   74.261665  114.452393  109.175534
# 4     119.753930   99.374723  130.509610   74.261665  114.452393  109.175534
# ...          ...         ...         ...         ...         ...         ...
# 2438  110.280775  131.083235  112.046128  103.479049   74.943352  138.581705
# 2439  110.280775  131.083235  112.046128  103.479049   74.943352  138.581705
# 2440  110.280775  131.083235  112.046128  103.479049   74.943352  138.581705
# 2441  110.280775  131.083235  112.046128  103.479049   74.943352  138.581705
# 2442  110.280775  131.083235  112.046128  103.479049   74.943352  138.581705
#
#               45          46          47
# 0     135.113346   90.649533  122.847967
# 1     135.113346   90.649533  122.847967
# 2     135.113346   90.649533  122.847967
# 3     135.113346   90.649533  122.847967
# 4     135.113346   90.649533  122.847967
# ...          ...         ...         ...
# 2438  124.544305  114.741035   94.729096
# 2439  124.544305  114.741035   94.729096
# 2440  124.544305  114.741035   94.729096
# 2441  124.544305  114.741035   94.729096
# 2442  124.544305  114.741035   94.729096
#
# [2443 rows x 48 columns]

# %%
position_data = pd.read_excel('real x-y-z positions of 2443 locations.xlsx', header=None)

# %%
position_data
# Out:
#               0          1      2
# 0    -45.581275  30.239368 -60.00
# 1    -45.188830  30.181623 -59.96
# 2    -44.791865  30.131806 -59.92
# 3    -44.390422  30.089935 -59.88
# 4    -43.984540  30.056029 -59.84
# ...         ...        ...    ...
# 2438 -59.939858  51.788725  37.52
# 2439 -59.963718  51.389997  37.56
# 2440 -59.981583  50.990713  37.60
# 2441 -59.993448  50.591032  37.64
# 2442 -59.999315  50.191116  37.68
#
# [2443 rows x 3 columns]

# %% [markdown]
# # Data Engineering

# %% [markdown]
# ### Sensors Data -- Labeling Columns

# %%
Sensors_Number_of_Columns = sensors_data.shape[1]

# %%
Sensors_columns = ["sensor" + str(x) for x in range(1,Sensors_Number_of_Columns + 1)]
sensors_data.columns = (Sensors_columns)

# %%
sensors_data
# Out:
#          sensor1     sensor2     sensor3     sensor4     sensor5     sensor6  \
# 0     103.365475  131.254765   82.406446  118.490072  124.741424  148.572789
# 1     103.365475  131.254765   82.406446  118.490072  124.741424  148.572789
# 2     103.365475  131.254765   82.406446  118.490072  124.741424  148.572789
# 3     103.365475  131.254765   82.406446  118.490072  124.741424  148.572789
# 4     103.365475  131.254765   82.406446  118.490072  124.741424  148.572789
# ...          ...         ...         ...         ...         ...         ...
# 2438  130.845198  115.244199  106.851047   78.347576  153.056587  140.522035
# 2439  130.845198  115.244199  106.851047   78.347576  153.056587  140.522035
# 2440  130.845198  115.244199  106.851047   78.347576  153.056587  140.522035
# 2441  130.845198  115.244199  106.851047   78.347576  153.056587  140.522035
# 2442  130.845198  115.244199  106.851047   78.347576  153.056587  140.522035
#
#          sensor7     sensor8     sensor9    sensor10  ...    sensor39  \
# 0     110.782852  137.480311  101.466941  123.421399  ...  107.203207
# 1     110.782852  137.480311  101.466941  123.421399  ...  107.203207
# 2     110.782852  137.480311  101.466941  123.421399  ...  107.203207
# 3     110.782852  137.480311  101.466941  123.421399  ...  107.203207
# 4     110.782852  137.480311  101.466941  123.421399  ...  107.203207
# ...          ...         ...         ...         ...  ...         ...
# 2438  133.823333  116.302351  121.182268  110.310482  ...  119.411902
# 2439  133.823333  116.302351  121.182268  110.310482  ...  119.411902
# 2440  133.823333  116.302351  121.182268  110.310482  ...  119.411902
# 2441  133.823333  116.302351  121.182268  110.310482  ...  119.411902
# 2442  133.823333  116.302351  121.182268  110.310482  ...  119.411902
#
#         sensor40    sensor41    sensor42    sensor43    sensor44    sensor45  \
# 0     119.753930   99.374723  130.509610   74.261665  114.452393  109.175534
# 1     119.753930   99.374723  130.509610   74.261665  114.452393  109.175534
# 2     119.753930   99.374723  130.509610   74.261665  114.452393  109.175534
# 3     119.753930   99.374723  130.509610   74.261665  114.452393  109.175534
# 4     119.753930   99.374723  130.509610   74.261665  114.452393  109.175534
# ...          ...         ...         ...         ...         ...         ...
# 2438  110.280775  131.083235  112.046128  103.479049   74.943352  138.581705
# 2439  110.280775  131.083235  112.046128  103.479049   74.943352  138.581705
# 2440  110.280775  131.083235  112.046128  103.479049   74.943352  138.581705
# 2441  110.280775  131.083235  112.046128  103.479049   74.943352  138.581705
# 2442  110.280775  131.083235  112.046128  103.479049   74.943352  138.581705
#
#         sensor46    sensor47    sensor48
# 0     135.113346   90.649533  122.847967
# 1     135.113346   90.649533  122.847967
# 2     135.113346   90.649533  122.847967
# 3     135.113346   90.649533  122.847967
# 4     135.113346   90.649533  122.847967
# ...          ...         ...         ...
# 2438  124.544305  114.741035   94.729096
# 2439  124.544305  114.741035   94.729096
# 2440  124.544305  114.741035   94.729096
# 2441  124.544305  114.741035   94.729096
# 2442  124.544305  114.741035   94.729096
#
# [2443 rows x 48 columns]

# %% [markdown]
# ### Converting to Pandas Dataframe

# %%
sensors_data = pd.DataFrame(sensors_data)

# %% [markdown]
# ### Position Data -- Labeling Columns

# %%
position_data.columns = ['Pos X', 'Pos Y', 'Pos Z']

# %%
position_data
# Out:
#           Pos X      Pos Y  Pos Z
# 0    -45.581275  30.239368 -60.00
# 1    -45.188830  30.181623 -59.96
# 2    -44.791865  30.131806 -59.92
# 3    -44.390422  30.089935 -59.88
# 4    -43.984540  30.056029 -59.84
# ...         ...        ...    ...
# 2438 -59.939858  51.788725  37.52
# 2439 -59.963718  51.389997  37.56
# 2440 -59.981583  50.990713  37.60
# 2441 -59.993448  50.591032  37.64
# 2442 -59.999315  50.191116  37.68
#
# [2443 rows x 3 columns]

# %% [markdown]
# ### Converting to Pandas Dataframe

# %%
position_data = pd.DataFrame(position_data)

# %% [markdown]
# # Taking Sensor 01 - Sensor 16

# %%
raw_data = pd.concat([sensors_data.iloc[:,:16], position_data], axis=1)
raw_data
# Out:
#          sensor1     sensor2     sensor3     sensor4     sensor5     sensor6  \
# 0     103.365475  131.254765   82.406446  118.490072  124.741424  148.572789
# 1     103.365475  131.254765   82.406446  118.490072  124.741424  148.572789
# 2     103.365475  131.254765   82.406446  118.490072  124.741424  148.572789
# 3     103.365475  131.254765   82.406446  118.490072  124.741424  148.572789
# 4     103.365475  131.254765   82.406446  118.490072  124.741424  148.572789
# ...          ...         ...         ...         ...         ...         ...
# 2438  130.845198  115.244199  106.851047   78.347576  153.056587  140.522035
# 2439  130.845198  115.244199  106.851047   78.347576  153.056587  140.522035
# 2440  130.845198  115.244199  106.851047   78.347576  153.056587  140.522035
# 2441  130.845198  115.244199  106.851047   78.347576  153.056587  140.522035
# 2442  130.845198  115.244199  106.851047   78.347576  153.056587  140.522035
#
#          sensor7     sensor8     sensor9    sensor10   sensor11    sensor12  \
# 0     110.782852  137.480311  101.466941  123.421399  79.551255  109.658522
# 1     110.782852  137.480311  101.466941  123.421399  79.551255  109.658522
# 2     110.782852  137.480311  101.466941  123.421399  79.551255  109.658522
# 3     110.782852  137.480311  101.466941  123.421399  79.551255  109.658522
# 4     110.782852  137.480311  101.466941  123.421399  79.551255  109.658522
# ...          ...         ...         ...         ...        ...         ...
# 2438  133.823333  116.302351  121.182268  110.310482  94.718210   69.185381
# 2439  133.823333  116.302351  121.182268  110.310482  94.718210   69.185381
# 2440  133.823333  116.302351  121.182268  110.310482  94.718210   69.185381
# 2441  133.823333  116.302351  121.182268  110.310482  94.718210   69.185381
# 2442  133.823333  116.302351  121.182268  110.310482  94.718210   69.185381
#
#         sensor13    sensor14    sensor15    sensor16      Pos X      Pos Y  \
# 0     121.671697  139.921001  108.602786  127.546015 -45.581275  30.239368
# 1     121.671697  139.921001  108.602786  127.546015 -45.188830  30.181623
# 2     121.671697  139.921001  108.602786  127.546015 -44.791865  30.131806
# 3     121.671697  139.921001  108.602786  127.546015 -44.390422  30.089935
# 4     121.671697  139.921001  108.602786  127.546015 -43.984540  30.056029
# ...          ...         ...         ...         ...        ...        ...
# 2438  147.585950  136.705821  125.037299  112.888952 -59.939858  51.788725
# 2439  147.585950  136.705821  125.037299  112.888952 -59.963718  51.389997
# 2440  147.585950  136.705821  125.037299  112.888952 -59.981583  50.990713
# 2441  147.585950  136.705821  125.037299  112.888952 -59.993448  50.591032
# 2442  147.585950  136.705821  125.037299  112.888952 -59.999315  50.191116
#
#       Pos Z
# 0    -60.00
# 1    -59.96
# 2    -59.92
# 3    -59.88
# 4    -59.84
# ...     ...
# 2438  37.52
# 2439  37.56
# 2440  37.60
# 2441  37.64
# 2442  37.68
#
# [2443 rows x 19 columns]

# %% [markdown]
# # Split the data into training and testing sets

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(sensors_data, position_data, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#          sensor1     sensor2     sensor3     sensor4     sensor5     sensor6  \
# 233   137.881517  153.165243  115.871574  137.406585  112.526032  135.466550
# 433   121.592208  139.058026   86.335605  112.792428  130.389895  146.267373
# 1430  145.771325  144.778557  117.656261  118.072187  126.463228  129.171448
# 307   127.945292  147.421209  113.727319  135.577414  104.027441  126.791389
# 2197  140.479449  130.043474  130.979969  115.610718  122.947593  107.437010
# ...          ...         ...         ...         ...         ...         ...
# 1638  131.484235  128.208485  110.374820  108.586940  125.997951  121.476007
# 1095  127.067786  131.636548   87.134422   99.243018  140.639940  147.382136
# 1130  123.972924  130.783089   84.240653   97.925160  144.913317  150.133795
# 1294  117.190655  120.592002   96.872234  101.981039  129.046835  133.089505
# 860   139.956869  150.417225  118.141071  130.418639  114.598147  127.566352
#
#          sensor7     sensor8     sensor9    sensor10  ...    sensor39  \
# 233    71.723841  110.006074  136.787768  148.064769  ...   66.017527
# 433    99.826221  119.987946  119.634796  130.704687  ...   94.584263
# 1430   86.779440   90.997365  140.201692  140.003560  ...   70.534530
# 307    81.781185  113.726384  127.379462  140.019466  ...   76.606800
# 2197  107.938768   88.593358  134.119687  126.435584  ...   86.151970
# ...          ...         ...         ...         ...  ...         ...
# 1638  103.909611   99.945705  125.277444  123.634429  ...   87.653681
# 1095  111.281736  118.231354  122.493099  125.273887  ...  101.760375
# 1130  114.828089  121.051632  119.591640  122.401914  ...  107.283387
# 1294  113.339273  117.095254  111.655741  113.163124  ...  104.802458
# 860    81.158577   98.930350  137.830975  141.822428  ...   68.627831
#
#         sensor40    sensor41    sensor42    sensor43    sensor44    sensor45  \
# 233    85.496544  120.899409  142.309886   92.561021  120.028485  110.535489
# 433   103.701592  114.821028  133.999763   70.894511  103.338968  119.188531
# 1430   72.403997  132.179260  134.789874   97.080373   99.628982  122.543705
# 307    93.187422  112.670539  133.626840   94.243620  118.776527  100.195145
# 2197   77.977558  128.403999  114.201804  113.195831   95.589572  118.116946
# ...          ...         ...         ...         ...         ...         ...
# 1638   86.493576  121.246788  117.152298   96.148435   90.989753  115.804488
# 1095  106.238368  120.530123  126.555193   79.594324   92.938511  128.417926
# 1130  110.861847  123.100926  129.317637   80.236525   92.071230  128.530139
# 1294  106.182501  110.929615  114.110396   88.953359   95.361876  116.105467
# 860    78.371937  124.802738  135.087405   96.613522  111.452997  113.833996
#
#         sensor46    sensor47    sensor48
# 233   134.283266   69.691319  107.978085
# 433   136.770470   80.173685  108.820874
# 1430  125.658668   84.348983   84.653341
# 307   126.064765   76.141321  108.324982
# 2197  103.764831  102.943053   83.082239
# ...          ...         ...         ...
# 1638  114.697407   93.329829   89.521456
# 1095  134.049607   91.284220  101.472427
# 1130  135.910449   97.377663  104.276325
# 1294  117.990819   97.524751  102.491711
# 860   126.712584   76.422883   97.591363
#
# [1954 rows x 48 columns]

# %%
y_train
# Out:
#           Pos X      Pos Y  Pos Z
# 233   59.678117  54.115562 -50.68
# 433  -19.191177  62.122007 -42.68
# 1430  45.890531  69.708995  -2.80
# 307   48.255475  30.881811 -47.72
# 2197  46.396180  30.387490  27.88
# ...         ...        ...    ...
# 1638  11.378450  42.552019   5.52
# 1095 -36.900143  69.397796 -16.20
# 1130 -50.886002  67.974162 -14.80
# 1294 -28.195387  33.407817  -8.24
# 860   59.591095  54.630197 -25.60
#
# [1954 rows x 3 columns]

# %% [markdown]
# # Machine Learning

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.ensemble import GradientBoostingRegressor

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, median_absolute_error
from sklearn.metrics import explained_variance_score, max_error, mean_squared_log_error

# %%
# Initialize the models
models = [LinearRegression(), DecisionTreeRegressor(), RandomForestRegressor(), KNeighborsRegressor(),  XGBRegressor()]

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, median_absolute_error, explained_variance_score
import time

# Train and evaluate each model
for model in models:
    start_time = time.time()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    end_time = time.time()
    
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    
    print(type(model).__name__)
    print("Accuracy:", model.score(X_test, y_test))
    print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
    print("Root Mean Squared Error:", rmse)
    print("R2 Score:", r2_score(y_test, y_pred))
    print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
    print("Median Absolute Error:", median_absolute_error(y_test, y_pred))
    print("Explained Variance Score:", explained_variance_score(y_test, y_pred))
    print("Time taken:", end_time - start_time)
    print("="*100)
# Out:
# LinearRegression
# Accuracy: 0.9992972371252359
# Mean Squared Error: 0.33734040693871475
# Root Mean Squared Error: 0.5801380415042577
# R2 Score: 0.9992972371252359
# Mean Absolute Error: 0.4686771710471673
# Median Absolute Error: 0.40801188598763477
# Explained Variance Score: 0.9992973685085328
# Time taken: 0.006499528884887695
# ====================================================================================================
# DecisionTreeRegressor
# Accuracy: 0.9951148230878276
# Mean Squared Error: 2.934124496690876
# Root Mean Squared Error: 1.6678833977072725
# R2 Score: 0.9951148230878276
# Mean Absolute Error: 0.5899094394331151
# Median Absolute Error: 0.31927009955493446
# Explained Variance Score: 0.9951187438504462
# Time taken: 0.042000770568847656
# ====================================================================================================
# RandomForestRegressor
# Accuracy: 0.9996302991625644
# Mean Squared Error: 0.1681117969379103
# Root Mean Squared Error: 0.4089957587411446
# R2 Score: 0.9996302991625644
# Mean Absolute Error: 0.21777659969131768
# Median Absolute Error: 0.10800535517721599
# Explained Variance Score: 0.9996316453059774
# Time taken: 2.444607973098755
# ====================================================================================================
# KNeighborsRegressor
# Accuracy: 0.9998342041184983
# Mean Squared Error: 0.06155014152066099
# Root Mean Squared Error: 0.21454675449108337
# R2 Score: 0.9998342041184983
# Mean Absolute Error: 0.14558631214838702
# Median Absolute Error: 0.11903881661061355
# Explained Variance Score: 0.9998354177144461
# Time taken: 1.355550765991211
# ====================================================================================================
# XGBRegressor
# Accuracy: 0.9981123033722358
# Mean Squared Error: 0.682073023719172
# Root Mean Squared Error: 0.8033056943936056
# R2 Score: 0.9981123033722358
# Mean Absolute Error: 0.487675157101779
# Median Absolute Error: 0.28670911725070053
# Explained Variance Score: 0.9981127703623568
# Time taken: 20.1499981880188
# ====================================================================================================

# %% [markdown]
# # Cross Validation

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score, mean_absolute_error
import time


X = sensors_data
y = position_data

#Define models
models = [LinearRegression(), DecisionTreeRegressor(), RandomForestRegressor(), KNeighborsRegressor(), XGBRegressor()]

#Define k-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

#Train and evaluate each model using k-fold cross-validation
for model in models:
    # Evaluate the performance of the model using k-fold cross-validation
    scores_mse = []
    scores_mae = []
    scores_rmse = []
    times = []
    for i, (train_index, test_index) in enumerate(kfold.split(X)):
        start_time = time.time()
        
        X_train_fold, X_val_fold = X.iloc[train_index], X.iloc[test_index]
        y_train_fold, y_val_fold = y.iloc[train_index], y.iloc[test_index]
        model.fit(X_train_fold, y_train_fold)
        y_pred_fold = model.predict(X_val_fold)
        
        
        mse = mean_squared_error(y_val_fold, y_pred_fold)
        mae = mean_absolute_error(y_val_fold, y_pred_fold)
        rmse = np.sqrt(mse)
        end_time = time.time()
        time_taken = end_time - start_time
        scores_mse.append(mse)
        scores_mae.append(mae)
        scores_rmse.append(rmse)
        times.append(time_taken)
        print(f"Model: {type(model).__name__}")
        print(f"Fold {i+1} - Mean Squared Error (MSE): {mse:.2f}")
        print(f"Fold {i+1} - Mean Absolute Error (MAE): {mae:.2f}")
        print(f"Fold {i+1} - Root Mean Squared Error (RMSE): {rmse:.2f}")
        print(f"Fold {i+1} - Time taken: {time_taken:.2f} seconds")
    
    # Calculate mean time and results for all the folds
    mean_mse = np.mean(scores_mse)
    mean_mae = np.mean(scores_mae)
    mean_rmse = np.mean(scores_rmse)
    mean_time = np.mean(times)

    # Print the mean results of the folds
    print(f"Mean MSE: {mean_mse:.2f}")
    print(f"Mean MAE: {mean_mae:.2f}")
    print(f"Mean RMSE: {mean_rmse:.2f}")
    print(f"Mean time: {mean_time:.2f} seconds")
    print("-" * 50)
# Out:
# Model: LinearRegression
# Fold 1 - Mean Squared Error (MSE): 0.34
# Fold 1 - Mean Absolute Error (MAE): 0.47
# Fold 1 - Root Mean Squared Error (RMSE): 0.58
# Fold 1 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 2 - Mean Squared Error (MSE): 0.35
# Fold 2 - Mean Absolute Error (MAE): 0.46
# Fold 2 - Root Mean Squared Error (RMSE): 0.59
# Fold 2 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 3 - Mean Squared Error (MSE): 0.34
# Fold 3 - Mean Absolute Error (MAE): 0.47
# Fold 3 - Root Mean Squared Error (RMSE): 0.59
# Fold 3 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 4 - Mean Squared Error (MSE): 0.36
# Fold 4 - Mean Absolute Error (MAE): 0.47
# Fold 4 - Root Mean Squared Error (RMSE): 0.60
# Fold 4 - Time taken: 0.01 seconds
# Model: LinearRegression
# Fold 5 - Mean Squared Error (MSE): 0.33
# Fold 5 - Mean Absolute Error (MAE): 0.46
# Fold 5 - Root Mean Squared Error (RMSE): 0.57
# Fold 5 - Time taken: 0.01 seconds
# Mean MSE: 0.34
# Mean MAE: 0.46
# Mean RMSE: 0.59
# Mean time: 0.01 seconds
# --------------------------------------------------
# Model: DecisionTreeRegressor
# Fold 1 - Mean Squared Error (MSE): 2.84
# Fold 1 - Mean Absolute Error (MAE): 0.58
# Fold 1 - Root Mean Squared Error (RMSE): 1.68
# Fold 1 - Time taken: 0.07 seconds
# Model: DecisionTreeRegressor
# Fold 2 - Mean Squared Error (MSE): 3.49
# Fold 2 - Mean Absolute Error (MAE): 0.58
# Fold 2 - Root Mean Squared Error (RMSE): 1.87
# Fold 2 - Time taken: 0.07 seconds
# Model: DecisionTreeRegressor
# Fold 3 - Mean Squared Error (MSE): 0.58
# Fold 3 - Mean Absolute Error (MAE): 0.45
# Fold 3 - Root Mean Squared Error (RMSE): 0.76
# Fold 3 - Time taken: 0.07 seconds
# Model: DecisionTreeRegressor
# Fold 4 - Mean Squared Error (MSE): 3.53
# Fold 4 - Mean Absolute Error (MAE): 0.60
# Fold 4 - Root Mean Squared Error (RMSE): 1.88
# Fold 4 - Time taken: 0.07 seconds
# Model: DecisionTreeRegressor
# Fold 5 - Mean Squared Error (MSE): 4.09
# Fold 5 - Mean Absolute Error (MAE): 0.58
# Fold 5 - Root Mean Squared Error (RMSE): 2.02
# Fold 5 - Time taken: 0.07 seconds
# Mean MSE: 2.91
# Mean MAE: 0.56
# Mean RMSE: 1.64
# Mean time: 0.07 seconds
# --------------------------------------------------
# Model: RandomForestRegressor
# Fold 1 - Mean Squared Error (MSE): 0.17
# Fold 1 - Mean Absolute Error (MAE): 0.22
# Fold 1 - Root Mean Squared Error (RMSE): 0.41
# Fold 1 - Time taken: 3.87 seconds
# Model: RandomForestRegressor
# Fold 2 - Mean Squared Error (MSE): 0.20
# Fold 2 - Mean Absolute Error (MAE): 0.21
# Fold 2 - Root Mean Squared Error (RMSE): 0.45
# Fold 2 - Time taken: 3.87 seconds
# Model: RandomForestRegressor
# Fold 3 - Mean Squared Error (MSE): 0.12
# Fold 3 - Mean Absolute Error (MAE): 0.20
# Fold 3 - Root Mean Squared Error (RMSE): 0.35
# Fold 3 - Time taken: 3.87 seconds
# Model: RandomForestRegressor
# Fold 4 - Mean Squared Error (MSE): 0.09
# Fold 4 - Mean Absolute Error (MAE): 0.18
# Fold 4 - Root Mean Squared Error (RMSE): 0.29
# Fold 4 - Time taken: 3.88 seconds
# Model: RandomForestRegressor
# Fold 5 - Mean Squared Error (MSE): 0.19
# Fold 5 - Mean Absolute Error (MAE): 0.21
# Fold 5 - Root Mean Squared Error (RMSE): 0.44
# Fold 5 - Time taken: 3.89 seconds
# Mean MSE: 0.16
# Mean MAE: 0.20
# Mean RMSE: 0.39
# Mean time: 3.87 seconds
# --------------------------------------------------
# Model: KNeighborsRegressor
# Fold 1 - Mean Squared Error (MSE): 0.05
# Fold 1 - Mean Absolute Error (MAE): 0.14
# Fold 1 - Root Mean Squared Error (RMSE): 0.22
# Fold 1 - Time taken: 0.09 seconds
# Model: KNeighborsRegressor
# Fold 2 - Mean Squared Error (MSE): 0.07
# Fold 2 - Mean Absolute Error (MAE): 0.16
# Fold 2 - Root Mean Squared Error (RMSE): 0.27
# Fold 2 - Time taken: 0.11 seconds
# Model: KNeighborsRegressor
# Fold 3 - Mean Squared Error (MSE): 0.08
# Fold 3 - Mean Absolute Error (MAE): 0.16
# Fold 3 - Root Mean Squared Error (RMSE): 0.28
# Fold 3 - Time taken: 0.13 seconds
# Model: KNeighborsRegressor
# Fold 4 - Mean Squared Error (MSE): 0.07
# Fold 4 - Mean Absolute Error (MAE): 0.16
# Fold 4 - Root Mean Squared Error (RMSE): 0.26
# Fold 4 - Time taken: 0.11 seconds
# Model: KNeighborsRegressor
# Fold 5 - Mean Squared Error (MSE): 0.07
# Fold 5 - Mean Absolute Error (MAE): 0.16
# Fold 5 - Root Mean Squared Error (RMSE): 0.26
# Fold 5 - Time taken: 0.11 seconds
# Mean MSE: 0.07
# Mean MAE: 0.15
# Mean RMSE: 0.26
# Mean time: 0.11 seconds
# --------------------------------------------------
# Model: XGBRegressor
# Fold 1 - Mean Squared Error (MSE): 0.68
# Fold 1 - Mean Absolute Error (MAE): 0.49
# Fold 1 - Root Mean Squared Error (RMSE): 0.83
# Fold 1 - Time taken: 11.64 seconds
# Model: XGBRegressor
# Fold 2 - Mean Squared Error (MSE): 0.82
# Fold 2 - Mean Absolute Error (MAE): 0.51
# Fold 2 - Root Mean Squared Error (RMSE): 0.91
# Fold 2 - Time taken: 11.64 seconds
# Model: XGBRegressor
# Fold 3 - Mean Squared Error (MSE): 1.11
# Fold 3 - Mean Absolute Error (MAE): 0.56
# Fold 3 - Root Mean Squared Error (RMSE): 1.05
# Fold 3 - Time taken: 9.03 seconds
# Model: XGBRegressor
# Fold 4 - Mean Squared Error (MSE): 0.75
# Fold 4 - Mean Absolute Error (MAE): 0.52
# Fold 4 - Root Mean Squared Error (RMSE): 0.87
# Fold 4 - Time taken: 2.86 seconds
# Model: XGBRegressor
# Fold 5 - Mean Squared Error (MSE): 0.86
# Fold 5 - Mean Absolute Error (MAE): 0.51
# Fold 5 - Root Mean Squared Error (RMSE): 0.93
# Fold 5 - Time taken: 2.33 seconds
# Mean MSE: 0.84
# Mean MAE: 0.52
# Mean RMSE: 0.92
# Mean time: 7.50 seconds
# --------------------------------------------------
